# %%
def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument(
        "--data_path",
        type=str,
        required=True,
        help="The path to data used for prediction.",
    )
    parser.add_argument(
        "--model",
        type=str,
        default="westlake-repl/SaProt_650M_AF2",
        help="The name of a pretrained model or path to a model which you want to use for training. You can use your local models or models uploaded to hugging face.",
    )
    parser.add_argument(
        "--architecture",
        type=str,
        default="SaProt",
        help="The name of a model architecture. 'ESM2', 'SaProt' or 'LSTM'.",
    )
    parser.add_argument(
        "--model_path",
        type=str,
        required=True,
        help="The path to a model which you want to use for prediction.",
    )
    parser.add_argument(
        "--batch_size", type=int, default=4, help="Batch size."
    )
    parser.add_argument(
        "--seed",
        type=int,
        default=42,
        help="Set seed for reproducibility.",
    )
    parser.add_argument(
        "--use_amp",
        action="store_true",
        default=False,
        help="Use amp for mixed precision training.",
    )
    parser.add_argument(
        "--num_workers",
        type=int,
        default=4,
        help="Number of workers for data loading.",
    )
    parser.add_argument(
        "--max_length",
        type=int,
        default=512,
        help="Max length of input sequence. Two tokens are used fo <cls> and <eos> tokens. So the actual length of input sequence is max_length - 2. Padding or truncation is applied to make the length of input sequence equal to max_length.",
    )
    parser.add_argument(
        "--used_sequence",
        type=str,
        default="left",
        help="How to use input sequence. 'left': use the left part of the sequence, 'right': use the right part of the sequence, 'both': use both side of the sequence, 'internal': use the internal part of the sequence.",
    )
    parser.add_argument(
        "--padding_side",
        type=str,
        default="right",
        help="Padding side. 'right' or 'left'.",
    )
    parser.add_argument(
        "--output_dir",
        type=str,
        default="/home2/sagawa/protein-half-life-prediction/ver20_56_2/",
        help="Output directory.",
    )
    parser.add_argument(
        "--task",
        type=str,
        default="classification",
        help="Task. 'classification' or 'regression'.",
    )
    parser.add_argument(
        "--sequence_col",
        type=str,
        default="aa_foldseek",
        help="The column name of amino acid sequence.",
    )

    return parser.parse_args()

# %%
class config:
    data_path = "/home2/sagawa/protein-half-life-prediction/ver20_56_2/data/ver20_56_2.csv"
    model="facebook/esm2_t33_650M_UR50D"
    architecture = "ESM2"
    model_path = "/home2/sagawa/protein-half-life-prediction/ver20_56_2/outputs/ver20_56_2_20210909_1/model_0"
    batch_size = 4
    seed = 42
    use_amp = False
    num_workers = 4
    max_length = 512
    used_sequence = "left"
    padding_side = "right"
    output_dir = "/home2/sagawa/protein-half-life-prediction/ver20_56_2/"
    task = "classification"
    sequence_col = "aa_foldseek"
cfg = config()

# %%
from models import PLTNUM
import torch
model = PLTNUM(cfg)
model.load_state_dict(torch.load("/home2/sagawa/PLTNUM/classification/model_fold0.pth", map_location=torch.device('cpu'))["model"])
model
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t33_650M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PLTNUM(
#   (model): EsmModel(
#     (embeddings): EsmEmbeddings(
#       (word_embeddings): Embedding(33, 1280, padding_idx=1)
#       (dropout): Dropout(p=0.0, inplace=False)
#       (position_embeddings): Embedding(1026, 1280, padding_idx=1)
#     )
#     (encoder): EsmEncoder(
#       (layer): ModuleList(
#         (0-32): 33 x EsmLayer(
#           (attention): EsmAttention(
#             (self): EsmSelfAttention(
#               (query): Linear(in_features=1280, out_features=1280, bias=True)
#               (key): Linear(in_features=1280, out_features=1280, bias=True)
#               (value): Linear(in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#               (rotary_embeddings): RotaryEmbedding()
#             )
#             (output): EsmSelfOutput(
#               (dense): Linear(in_features=1280, out_features=1280, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (LayerNorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           )
#           (intermediate): EsmIntermediate(
#             (dense): Linear(in_features=1280, out_features=5120, bias=True)
#           )
#           (output): EsmOutput(
#             (dense): Linear(in_features=5120, out_features=1280, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (LayerNorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (emb_layer_norm_after): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (pooler): EsmPooler(
#       (dense): Linear(in_features=1280, out_features=1280, bias=True)
#       (activation): Tanh()
#     )
#     (contact_head): EsmContactPredictionHead(
#       (regression): Linear(in_features=660, out_features=1, bias=True)
#       (activation): Sigmoid()
#     )
#   )
#   (fc_dropout1): Dropout(p=0.8, inplace=False)
#   (fc_dropout2): Dropout(p=0.4, inplace=False)
#   (fc): Linear(in_features=1280, out_features=1, bias=True)
# )

# %%
torch.load("/home2/sagawa/PLTNUM/classification/model_fold0.pth", map_location=torch.device('cpu'))["model"]
# Out:
# OrderedDict([('model.embeddings.word_embeddings.weight',
#               tensor([[ 0.0540, -0.0574, -0.1302,  ..., -0.2233,  0.1189, -0.0651],
#                       [ 0.0614,  0.0292, -0.1028,  ..., -0.0330,  0.0668, -0.0575],
#                       [-0.0896, -0.0439, -0.0575,  ..., -0.0582,  0.0655, -0.1094],
#                       ...,
#                       [ 0.0023,  0.0143,  0.0514,  ..., -0.0193,  0.0112,  0.0053],
#                       [ 0.0731,  0.0470,  0.0346,  ...,  0.1118,  0.0465, -0.0243],
#                       [ 0.0492,  0.0254, -0.1112,  ..., -0.0257,  0.0599, -0.0614]])),
#              ('model.embeddings.position_embeddings.weight',
#               tensor([[ 0.0026,  0.0083,  0.0133,  ..., -0.0090,  0.0321,  0.0109],
#                       [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#                       [ 0.0140,  0.0045,  0.0005,  ...,  0.0225, -0.0110, -0.0185],
#                       ...,
#                       [ 0.0315,  0.0066, -0.0124,  ..., -0.0021, -0.0198,  0.0023],
#                       [ 0.0121,  0.0167,  0.0021,  ...,  0.0187, -0.0207, -0.0138],
#                       [ 0.0053,  0.0031,  0.0104,  ..., -0.0176, -0.0125,  0.0156]])),
#              ('model.encoder.layer.0.attention.self.query.weight',
#               tensor([[-0.0010,  0.0720, -0.0222,  ...,  0.0224,  0.0110, -0.0049],
#                       [ 0.0101, -0.0189, -0.0463,  ..., -0.0124,  0.0128,  0.0216],
#                       [-0.0039,  0.0036, -0.0530,  ...,  0.0401,  0.0003,  0.0037],
#                       ...,
#                       [-0.0082, -0.0037,  0.0052,  ...,  0.0121, -0.0035,  0.0119],
#                       [-0.0124, -0.0508, -0.1796,  ...,  0.0419, -0.0225,  0.0115],
#                       [ 0.0098,  0.0079, -0.0162,  ..., -0.0121, -0.0109, -0.0007]])),
#              ('model.encoder.layer.0.attention.self.query.bias',
#               tensor([ 0.0158,  0.0173,  0.0124,  ..., -0.0082,  0.5690,  0.0067])),
#              ('model.encoder.layer.0.attention.self.key.weight',
#               tensor([[-0.0154,  0.0167,  0.0126,  ...,  0.0096,  0.0017, -0.0173],
#                       [-0.0017, -0.0210,  0.0465,  ..., -0.0354,  0.0132,  0.0205],
#                       [-0.0053,  0.0444, -0.0267,  ..., -0.0385, -0.0087, -0.0227],
#                       ...,
#                       [-0.0137,  0.0128, -0.0014,  ...,  0.0203,  0.0037, -0.0168],
#                       [ 0.0145, -0.1591, -0.0610,  ..., -0.1398,  0.0040, -0.0051],
#                       [-0.0059, -0.0007,  0.0052,  ..., -0.0299, -0.0098, -0.0081]])),
#              ('model.encoder.layer.0.attention.self.key.bias',
#               tensor([ 0.0148, -0.0152,  0.0210,  ..., -0.0212, -0.0140, -0.0027])),
#              ('model.encoder.layer.0.attention.self.value.weight',
#               tensor([[-0.0126,  0.0043, -0.0156,  ...,  0.0052,  0.0156,  0.0156],
#                       [-0.0007,  0.1000, -0.0322,  ...,  0.0865,  0.0335,  0.0076],
#                       [ 0.0114,  0.0033, -0.0154,  ...,  0.0089, -0.0120, -0.0087],
#                       ...,
#                       [ 0.0233, -0.0097,  0.0137,  ...,  0.0098,  0.0254,  0.0019],
#                       [-0.0210,  0.0273, -0.0101,  ...,  0.0137,  0.0028,  0.0096],
#                       [ 0.0045,  0.0174, -0.0039,  ..., -0.0121,  0.0376,  0.0113]])),
#              ('model.encoder.layer.0.attention.self.value.bias',
#               tensor([-0.0109,  0.0282, -0.0008,  ..., -0.0077, -0.0314, -0.0105])),
#              ('model.encoder.layer.0.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.0.attention.output.dense.weight',
#               tensor([[-2.2805e-02, -4.2929e-02,  3.5805e-02,  ...,  8.4162e-03,
#                         5.8222e-02, -3.6890e-02],
#                       [ 5.8070e-02, -6.7157e-02, -1.7512e-02,  ..., -1.6311e-02,
#                         1.6970e-04, -1.0420e-01],
#                       [-1.2629e-02, -2.4866e-03,  1.5781e-02,  ..., -3.0989e-02,
#                         5.4859e-02, -3.5524e-02],
#                       ...,
#                       [-2.4611e-02, -1.7284e-02,  2.1919e-02,  ...,  6.8041e-02,
#                        -3.7192e-02, -3.2710e-02],
#                       [-1.1521e-02,  3.1871e-02, -2.9001e-02,  ...,  8.1517e-03,
#                        -5.4071e-05,  1.6370e-02],
#                       [ 1.5459e-02, -3.0153e-02, -6.2363e-03,  ...,  3.1608e-02,
#                         4.5019e-02,  1.0971e-02]])),
#              ('model.encoder.layer.0.attention.output.dense.bias',
#               tensor([ 0.0618, -0.0080,  0.0038,  ...,  0.0203, -0.0234, -0.0107])),
#              ('model.encoder.layer.0.attention.LayerNorm.weight',
#               tensor([ 0.0003,  0.0513,  0.0894,  ...,  0.0083, -0.0003,  0.0002])),
#              ('model.encoder.layer.0.attention.LayerNorm.bias',
#               tensor([ 1.1234e-03, -5.8691e-03,  1.1424e-02,  ..., -2.0222e-03,
#                       -2.0548e-05,  7.2370e-05])),
#              ('model.encoder.layer.0.intermediate.dense.weight',
#               tensor([[-0.0250,  0.0467, -0.0283,  ..., -0.0459, -0.0177, -0.0341],
#                       [-0.0889, -0.0306, -0.0114,  ..., -0.0164,  0.0369,  0.0213],
#                       [-0.0357,  0.0157,  0.0743,  ...,  0.0540,  0.1045, -0.1139],
#                       ...,
#                       [-0.0237,  0.0449,  0.0116,  ..., -0.0567,  0.0111, -0.0478],
#                       [-0.0061,  0.0502,  0.2140,  ..., -0.1098, -0.0912, -0.0449],
#                       [-0.0639, -0.1005, -0.0145,  ..., -0.1149, -0.1136, -0.0415]])),
#              ('model.encoder.layer.0.intermediate.dense.bias',
#               tensor([ 0.0556,  0.0409, -0.0082,  ...,  0.0081, -0.0119, -0.0193])),
#              ('model.encoder.layer.0.output.dense.weight',
#               tensor([[-0.0525, -0.1686, -0.0057,  ..., -0.0054,  0.0716,  0.0349],
#                       [ 0.1015,  0.1539,  0.1187,  ...,  0.0285,  0.0221, -0.0948],
#                       [-0.0638,  0.0428, -0.0321,  ..., -0.0210,  0.0930,  0.0721],
#                       ...,
#                       [-0.0094, -0.1809, -0.0465,  ..., -0.0037, -0.0753,  0.0155],
#                       [-0.0220,  0.0043, -0.0541,  ...,  0.0166, -0.0426, -0.0805],
#                       [-0.0228, -0.1844, -0.0276,  ..., -0.0174,  0.0015,  0.0259]])),
#              ('model.encoder.layer.0.output.dense.bias',
#               tensor([ 0.0231,  0.0007,  0.0468,  ..., -0.0660, -0.0250, -0.0328])),
#              ('model.encoder.layer.0.LayerNorm.weight',
#               tensor([0.2630, 0.3665, 0.0661,  ..., 0.0614, 0.0767, 0.0778])),
#              ('model.encoder.layer.0.LayerNorm.bias',
#               tensor([ 0.0388, -0.0270, -0.0656,  ...,  0.0933,  0.0705,  0.0792])),
#              ('model.encoder.layer.1.attention.self.query.weight',
#               tensor([[ 0.0376,  0.0007, -0.0093,  ..., -0.0278,  0.2951, -0.1014],
#                       [-0.0005, -0.1403, -0.0344,  ..., -0.0024, -0.0063,  0.0285],
#                       [ 0.2168,  0.0299,  0.0124,  ..., -0.0326,  0.0743, -0.0987],
#                       ...,
#                       [ 0.0496, -0.0521,  0.0120,  ..., -0.0025,  0.0984,  0.0396],
#                       [ 0.1589, -0.0062,  0.0706,  ..., -0.0069,  0.1702, -0.0630],
#                       [ 0.1325, -0.0207,  0.1199,  ...,  0.0346,  0.0186, -0.0015]])),
#              ('model.encoder.layer.1.attention.self.query.bias',
#               tensor([ 0.1207, -0.0511, -0.0469,  ..., -0.0065,  0.0014, -0.0083])),
#              ('model.encoder.layer.1.attention.self.key.weight',
#               tensor([[-0.1743,  0.0147,  0.1155,  ...,  0.0137, -0.0850,  0.0005],
#                       [ 0.0911, -0.0453,  0.0692,  ...,  0.0655,  0.0129,  0.0142],
#                       [-0.0400,  0.0603,  0.0201,  ...,  0.0621, -0.0935,  0.0020],
#                       ...,
#                       [ 0.0134, -0.0566, -0.0356,  ...,  0.0398, -0.0717, -0.1175],
#                       [-0.0210,  0.0552,  0.0622,  ..., -0.2123,  0.0185, -0.0349],
#                       [ 0.0602,  0.0547, -0.0663,  ..., -0.0971, -0.0385, -0.0415]])),
#              ('model.encoder.layer.1.attention.self.key.bias',
#               tensor([-0.0877,  0.0807,  0.0499,  ..., -0.0507, -0.0967, -0.0005])),
#              ('model.encoder.layer.1.attention.self.value.weight',
#               tensor([[ 0.0529, -0.0170, -0.0262,  ...,  0.0165, -0.0894, -0.0209],
#                       [-0.0359,  0.0150, -0.0110,  ..., -0.1097, -0.0742,  0.0734],
#                       [ 0.0065, -0.0657,  0.0476,  ...,  0.0272,  0.0230,  0.0107],
#                       ...,
#                       [-0.0059, -0.0662,  0.0105,  ...,  0.0727, -0.1176,  0.0191],
#                       [ 0.0090,  0.1124, -0.0749,  ...,  0.0538, -0.0314, -0.0683],
#                       [ 0.0404,  0.0339,  0.0533,  ...,  0.0195, -0.0305, -0.0960]])),
#              ('model.encoder.layer.1.attention.self.value.bias',
#               tensor([ 0.0030,  0.0104,  0.0001,  ..., -0.0016,  0.0220,  0.0068])),
#              ('model.encoder.layer.1.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.1.attention.output.dense.weight',
#               tensor([[-0.0003,  0.0335, -0.0065,  ...,  0.0454,  0.0525,  0.0147],
#                       [-0.0309,  0.0197,  0.0567,  ...,  0.0631,  0.0055, -0.0548],
#                       [ 0.0148,  0.0185,  0.0666,  ...,  0.0112, -0.0061, -0.0757],
#                       ...,
#                       [-0.0767,  0.0111, -0.0824,  ...,  0.0111, -0.1390,  0.0347],
#                       [-0.0819, -0.0272, -0.0476,  ...,  0.0294,  0.1894,  0.0354],
#                       [-0.0267, -0.0540, -0.0727,  ..., -0.0057,  0.0127,  0.0824]])),
#              ('model.encoder.layer.1.attention.output.dense.bias',
#               tensor([ 0.0593, -0.0319,  0.0515,  ..., -0.0850, -0.0291, -0.0188])),
#              ('model.encoder.layer.1.attention.LayerNorm.weight',
#               tensor([0.1175, 0.0822, 0.0792,  ..., 0.1778, 0.1075, 0.1178])),
#              ('model.encoder.layer.1.attention.LayerNorm.bias',
#               tensor([-0.0488,  0.0316, -0.0203,  ...,  0.0536,  0.0234,  0.0053])),
#              ('model.encoder.layer.1.intermediate.dense.weight',
#               tensor([[-3.0234e-02,  6.3647e-02, -2.3893e-02,  ..., -4.3580e-02,
#                        -2.1959e-02, -1.5514e-02],
#                       [-5.5472e-02, -1.0226e-01, -4.0204e-03,  ..., -1.8647e-01,
#                         1.0977e-01, -2.4295e-01],
#                       [-3.0110e-02,  2.5071e-02, -3.4869e-02,  ...,  2.6546e-02,
#                         2.6946e-02,  6.1301e-05],
#                       ...,
#                       [ 2.6203e-03, -1.1398e-02, -3.2700e-02,  ...,  2.0329e-02,
#                         1.0766e-02, -4.0275e-02],
#                       [-1.0147e-01, -2.8046e-02,  7.4162e-02,  ..., -1.4907e-01,
#                        -1.4753e-01,  1.7215e-01],
#                       [-1.8935e-02,  1.2513e-02, -3.6763e-02,  ..., -3.0627e-02,
#                        -3.0648e-03,  2.5642e-02]])),
#              ('model.encoder.layer.1.intermediate.dense.bias',
#               tensor([-0.1036, -0.0096, -0.0080,  ...,  0.0014, -0.0070, -0.1478])),
#              ('model.encoder.layer.1.output.dense.weight',
#               tensor([[ 0.0061, -0.1107, -0.0422,  ..., -0.0237,  0.0662,  0.0008],
#                       [ 0.0070,  0.0352,  0.0161,  ...,  0.0356, -0.1099,  0.0138],
#                       [-0.0090,  0.1258, -0.0161,  ..., -0.0112, -0.0244, -0.0067],
#                       ...,
#                       [ 0.0071, -0.0784,  0.0091,  ...,  0.0427, -0.0907, -0.0151],
#                       [-0.0116,  0.0556, -0.0366,  ..., -0.0542, -0.1338, -0.0015],
#                       [ 0.0026,  0.0843, -0.0083,  ..., -0.0562, -0.0165, -0.0011]])),
#              ('model.encoder.layer.1.output.dense.bias',
#               tensor([ 0.0003,  0.0619,  0.0502,  ..., -0.0892,  0.0059,  0.0128])),
#              ('model.encoder.layer.1.LayerNorm.weight',
#               tensor([0.4100, 0.4476, 0.3509,  ..., 0.3112, 0.2467, 0.2432])),
#              ('model.encoder.layer.1.LayerNorm.bias',
#               tensor([ 0.0902, -0.2198,  0.0312,  ..., -0.0071, -0.0963, -0.0486])),
#              ('model.encoder.layer.2.attention.self.query.weight',
#               tensor([[ 0.0431, -0.0233, -0.1518,  ...,  0.0420, -0.0709, -0.0021],
#                       [-0.0304, -0.0139, -0.2031,  ...,  0.0286, -0.1203,  0.0487],
#                       [-0.0238, -0.1383, -0.0711,  ...,  0.0059,  0.0206, -0.1622],
#                       ...,
#                       [ 0.0268, -0.0898, -0.1000,  ..., -0.0332, -0.0412, -0.2053],
#                       [-0.0623,  0.1836, -0.0075,  ..., -0.1741, -0.2626, -0.2706],
#                       [ 0.0003, -0.1742, -0.1804,  ..., -0.0091,  0.1203, -0.0640]])),
#              ('model.encoder.layer.2.attention.self.query.bias',
#               tensor([-0.0590, -0.0333,  0.0441,  ..., -0.0773, -0.0549, -0.0438])),
#              ('model.encoder.layer.2.attention.self.key.weight',
#               tensor([[-0.0358, -0.0519,  0.0442,  ...,  0.0645, -0.0524, -0.0889],
#                       [-0.0756, -0.0285,  0.0583,  ..., -0.0196,  0.1150,  0.0880],
#                       [ 0.0823,  0.1096, -0.1011,  ..., -0.0067, -0.1422,  0.0151],
#                       ...,
#                       [-0.0033, -0.3077, -0.1020,  ...,  0.1410, -0.0659, -0.0245],
#                       [ 0.0337,  0.0522,  0.0584,  ..., -0.0133, -0.0790,  0.0093],
#                       [-0.1243, -0.3026,  0.0702,  ...,  0.0415, -0.1655, -0.0230]])),
#              ('model.encoder.layer.2.attention.self.key.bias',
#               tensor([ 0.0124, -0.0391, -0.0358,  ...,  0.1092, -0.0354, -0.0022])),
#              ('model.encoder.layer.2.attention.self.value.weight',
#               tensor([[ 0.0888, -0.0030, -0.0259,  ..., -0.0384,  0.0289, -0.0208],
#                       [ 0.1227,  0.0009, -0.0666,  ..., -0.0621,  0.0723, -0.0005],
#                       [-0.0215, -0.0662,  0.0004,  ..., -0.0473, -0.0586,  0.0769],
#                       ...,
#                       [-0.1009, -0.1017, -0.0163,  ..., -0.2305, -0.1009, -0.0839],
#                       [-0.1140, -0.0410, -0.0304,  ..., -0.0396,  0.1272,  0.0513],
#                       [-0.0267, -0.0445,  0.0285,  ..., -0.0540, -0.1230, -0.0194]])),
#              ('model.encoder.layer.2.attention.self.value.bias',
#               tensor([ 0.0004,  0.0029,  0.0102,  ..., -0.0042, -0.0061, -0.0002])),
#              ('model.encoder.layer.2.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.2.attention.output.dense.weight',
#               tensor([[-0.1272, -0.0381,  0.1234,  ...,  0.0636,  0.0655, -0.0660],
#                       [ 0.0603,  0.0596,  0.1540,  ..., -0.0778, -0.1679,  0.0404],
#                       [-0.0569, -0.0010, -0.0938,  ...,  0.0358,  0.0304,  0.0102],
#                       ...,
#                       [ 0.0572,  0.0304, -0.0199,  ...,  0.1004,  0.0582,  0.0497],
#                       [-0.0278, -0.1403,  0.0050,  ...,  0.1719, -0.0763, -0.1441],
#                       [ 0.1154, -0.0355,  0.0172,  ...,  0.0253, -0.0325,  0.0836]])),
#              ('model.encoder.layer.2.attention.output.dense.bias',
#               tensor([ 0.0414,  0.0337,  0.0626,  ..., -0.0905, -0.0119,  0.0226])),
#              ('model.encoder.layer.2.attention.LayerNorm.weight',
#               tensor([0.1861, 0.1644, 0.1312,  ..., 0.2101, 0.1767, 0.1646])),
#              ('model.encoder.layer.2.attention.LayerNorm.bias',
#               tensor([-0.0627,  0.0243, -0.0444,  ...,  0.0395,  0.0192, -0.0109])),
#              ('model.encoder.layer.2.intermediate.dense.weight',
#               tensor([[ 0.0005,  0.0130, -0.0386,  ...,  0.0400, -0.0048, -0.0083],
#                       [ 0.0049,  0.0313,  0.0132,  ...,  0.0474,  0.1521, -0.0703],
#                       [-0.0491,  0.1571,  0.0497,  ...,  0.0649,  0.0067,  0.1678],
#                       ...,
#                       [-0.0545,  0.0142, -0.0348,  ...,  0.0052, -0.0019, -0.0178],
#                       [ 0.0694,  0.0662, -0.0158,  ...,  0.0011, -0.2074,  0.1599],
#                       [-0.0259, -0.0151, -0.0444,  ...,  0.0315, -0.0126,  0.0163]])),
#              ('model.encoder.layer.2.intermediate.dense.bias',
#               tensor([-0.1503, -0.0069, -0.0048,  ..., -0.0538, -0.0166, -0.2431])),
#              ('model.encoder.layer.2.output.dense.weight',
#               tensor([[-0.0156,  0.0961, -0.0572,  ..., -0.0524, -0.0276, -0.0213],
#                       [ 0.0148,  0.0138,  0.1047,  ...,  0.0387,  0.0358,  0.0264],
#                       [-0.0300, -0.0179, -0.1124,  ..., -0.0290,  0.0574, -0.0351],
#                       ...,
#                       [ 0.0099, -0.0575, -0.0932,  ...,  0.0156, -0.0838,  0.0050],
#                       [ 0.0051,  0.0457, -0.0220,  ...,  0.0050,  0.1424, -0.0133],
#                       [-0.0039, -0.0509,  0.0718,  ..., -0.0027, -0.0650,  0.0220]])),
#              ('model.encoder.layer.2.output.dense.bias',
#               tensor([ 0.0197,  0.0448,  0.0727,  ..., -0.0572, -0.0031,  0.0130])),
#              ('model.encoder.layer.2.LayerNorm.weight',
#               tensor([0.3839, 0.2934, 0.4406,  ..., 0.4303, 0.2801, 0.2842])),
#              ('model.encoder.layer.2.LayerNorm.bias',
#               tensor([ 0.0286, -0.0287,  0.0045,  ..., -0.0879, -0.0161,  0.0269])),
#              ('model.encoder.layer.3.attention.self.query.weight',
#               tensor([[-3.1031e-02, -6.7677e-02,  2.1492e-02,  ...,  1.0042e-01,
#                         9.2291e-02, -4.8545e-02],
#                       [-5.1178e-02, -4.0434e-02,  1.6741e-01,  ...,  3.0570e-02,
#                        -3.8031e-02,  3.6922e-02],
#                       [ 1.9197e-01, -2.7374e-01,  2.3736e-02,  ...,  2.1602e-01,
#                        -9.9894e-02,  3.3423e-03],
#                       ...,
#                       [-5.8708e-02, -1.4101e-04,  4.7613e-02,  ...,  2.6650e-02,
#                         8.1596e-02,  1.1928e-01],
#                       [ 5.0551e-02, -9.9336e-02,  2.1577e-01,  ..., -8.9315e-02,
#                         1.7838e-01, -9.7281e-02],
#                       [-5.6163e-02, -3.2533e-02,  3.0622e-03,  ...,  1.7698e-01,
#                        -8.9364e-02,  4.3972e-02]])),
#              ('model.encoder.layer.3.attention.self.query.bias',
#               tensor([-0.0375, -0.3056, -0.0355,  ...,  0.0372,  0.0011, -0.0179])),
#              ('model.encoder.layer.3.attention.self.key.weight',
#               tensor([[ 0.0966, -0.0118,  0.0328,  ..., -0.0433, -0.0123, -0.0044],
#                       [ 0.1005, -0.1231,  0.0731,  ...,  0.0071, -0.1180,  0.0648],
#                       [-0.0245, -0.0226, -0.1445,  ...,  0.0636, -0.0452,  0.0572],
#                       ...,
#                       [-0.0055, -0.0006, -0.2400,  ..., -0.0996,  0.0904,  0.0689],
#                       [-0.0942, -0.1997,  0.0984,  ..., -0.0393,  0.0577, -0.0784],
#                       [-0.0768,  0.0397, -0.0059,  ..., -0.0622, -0.0704,  0.0736]])),
#              ('model.encoder.layer.3.attention.self.key.bias',
#               tensor([-0.1473, -0.2824,  0.0091,  ..., -0.1230, -0.0486, -0.0694])),
#              ('model.encoder.layer.3.attention.self.value.weight',
#               tensor([[-0.0735, -0.0492,  0.0120,  ..., -0.0460, -0.0178,  0.0335],
#                       [-0.0047, -0.0296,  0.1164,  ...,  0.0008,  0.0630,  0.0604],
#                       [ 0.0147,  0.0268,  0.0566,  ..., -0.0359, -0.0268,  0.0700],
#                       ...,
#                       [-0.0601, -0.0675,  0.0100,  ..., -0.1492,  0.0872,  0.1108],
#                       [-0.0229, -0.0129,  0.0347,  ...,  0.0707, -0.0012, -0.0149],
#                       [ 0.1204, -0.0339,  0.0631,  ..., -0.0585, -0.0215,  0.0500]])),
#              ('model.encoder.layer.3.attention.self.value.bias',
#               tensor([ 0.0033, -0.0105, -0.0009,  ...,  0.0020,  0.0009, -0.0026])),
#              ('model.encoder.layer.3.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.3.attention.output.dense.weight',
#               tensor([[ 0.0344, -0.0513, -0.0491,  ...,  0.0728, -0.1359, -0.0600],
#                       [-0.0500, -0.0996, -0.1069,  ..., -0.1026, -0.2156, -0.1888],
#                       [-0.0118, -0.0783, -0.0520,  ..., -0.1273, -0.0368,  0.0600],
#                       ...,
#                       [ 0.0596, -0.0691, -0.0307,  ..., -0.0126,  0.1313, -0.0482],
#                       [ 0.1600,  0.0275,  0.0449,  ...,  0.0071,  0.1458, -0.0144],
#                       [-0.0639, -0.0747, -0.0996,  ..., -0.0325,  0.0103,  0.1377]])),
#              ('model.encoder.layer.3.attention.output.dense.bias',
#               tensor([ 0.0327,  0.0249,  0.0649,  ..., -0.0670,  0.0159,  0.0265])),
#              ('model.encoder.layer.3.attention.LayerNorm.weight',
#               tensor([0.2432, 0.2287, 0.1884,  ..., 0.2192, 0.2200, 0.1895])),
#              ('model.encoder.layer.3.attention.LayerNorm.bias',
#               tensor([-0.0425,  0.0128, -0.0374,  ...,  0.0158, -0.0086, -0.0213])),
#              ('model.encoder.layer.3.intermediate.dense.weight',
#               tensor([[-0.0232,  0.0171, -0.0034,  ...,  0.0942,  0.0467,  0.0106],
#                       [-0.2530, -0.0014,  0.0166,  ...,  0.1574, -0.0598,  0.1158],
#                       [-0.0205, -0.0174, -0.0460,  ...,  0.0274,  0.0099, -0.0403],
#                       ...,
#                       [-0.0453, -0.0059, -0.0534,  ...,  0.0425, -0.0157, -0.0104],
#                       [-0.0282,  0.0228,  0.0487,  ...,  0.0606,  0.1552, -0.0009],
#                       [ 0.0588, -0.0732, -0.0292,  ..., -0.0369,  0.1195, -0.0589]])),
#              ('model.encoder.layer.3.intermediate.dense.bias',
#               tensor([-0.1612, -0.0182, -0.1569,  ..., -0.1869,  0.0019, -0.0293])),
#              ('model.encoder.layer.3.output.dense.weight',
#               tensor([[-0.0316, -0.0245, -0.0380,  ..., -0.0134,  0.1370, -0.0303],
#                       [ 0.0347, -0.0593,  0.0191,  ...,  0.0289, -0.1667,  0.0539],
#                       [-0.0355, -0.0002,  0.0163,  ...,  0.0123,  0.1423,  0.0757],
#                       ...,
#                       [ 0.0166, -0.0511, -0.0021,  ..., -0.0022,  0.1031,  0.0215],
#                       [-0.0157, -0.1347, -0.0263,  ..., -0.0292, -0.0166,  0.0285],
#                       [-0.0400, -0.0165, -0.0204,  ...,  0.0199, -0.1129,  0.2183]])),
#              ('model.encoder.layer.3.output.dense.bias',
#               tensor([-0.0126,  0.0486,  0.0188,  ..., -0.0080, -0.0177,  0.0007])),
#              ('model.encoder.layer.3.LayerNorm.weight',
#               tensor([0.3832, 0.3176, 0.5067,  ..., 0.4364, 0.3373, 0.3744])),
#              ('model.encoder.layer.3.LayerNorm.bias',
#               tensor([ 0.1067, -0.0579,  0.1059,  ..., -0.1459,  0.0560,  0.0579])),
#              ('model.encoder.layer.4.attention.self.query.weight',
#               tensor([[-6.6196e-02, -1.4649e-01, -1.5757e-01,  ..., -3.9732e-02,
#                         1.4669e-01, -7.4850e-02],
#                       [-2.2521e-02, -6.5022e-02,  2.3930e-02,  ..., -1.6715e-01,
#                         7.1043e-02, -2.6536e-02],
#                       [-9.6444e-02,  4.2111e-02, -1.3581e-01,  ...,  2.2895e-01,
#                         1.4233e-01, -1.1036e-02],
#                       ...,
#                       [-1.6640e-01, -2.3491e-02, -6.1459e-02,  ..., -1.0529e-01,
#                        -6.8825e-02,  7.8812e-03],
#                       [ 8.9498e-02,  9.5617e-02,  3.7616e-03,  ..., -3.9031e-02,
#                        -1.0403e-01,  1.1771e-02],
#                       [ 2.2030e-02, -1.0221e-04, -1.6601e-01,  ...,  4.6233e-02,
#                         8.4872e-02,  8.5626e-02]])),
#              ('model.encoder.layer.4.attention.self.query.bias',
#               tensor([-0.2370,  0.0110, -0.0043,  ...,  0.0047, -0.0053,  0.0233])),
#              ('model.encoder.layer.4.attention.self.key.weight',
#               tensor([[-0.0654,  0.1477, -0.0022,  ...,  0.0176, -0.0908,  0.0818],
#                       [-0.0385,  0.0246, -0.2044,  ..., -0.1237,  0.0359,  0.0987],
#                       [-0.1666,  0.0407, -0.0419,  ..., -0.1349,  0.1769, -0.1743],
#                       ...,
#                       [ 0.0497, -0.0088,  0.1734,  ...,  0.1367, -0.0896,  0.0028],
#                       [-0.1156, -0.0220,  0.0450,  ..., -0.0382,  0.0265,  0.1635],
#                       [ 0.2303, -0.0187, -0.0444,  ..., -0.1225, -0.1627, -0.0388]])),
#              ('model.encoder.layer.4.attention.self.key.bias',
#               tensor([ 0.3557, -0.0185,  0.0012,  ..., -0.1130,  0.0539, -0.0224])),
#              ('model.encoder.layer.4.attention.self.value.weight',
#               tensor([[-0.0713,  0.0282, -0.0146,  ..., -0.1607,  0.2975,  0.1138],
#                       [ 0.0851, -0.1107,  0.0769,  ..., -0.0396, -0.1429,  0.0211],
#                       [-0.0090,  0.0396, -0.1256,  ..., -0.0687,  0.0651, -0.1878],
#                       ...,
#                       [ 0.1082,  0.0164, -0.1231,  ...,  0.1006,  0.0151, -0.1094],
#                       [-0.0609, -0.0117,  0.0273,  ..., -0.0067, -0.1583,  0.0658],
#                       [ 0.0888, -0.1020, -0.1569,  ..., -0.1028, -0.1094,  0.0573]])),
#              ('model.encoder.layer.4.attention.self.value.bias',
#               tensor([ 0.0048,  0.0096,  0.0091,  ...,  0.0051,  0.0093, -0.0047])),
#              ('model.encoder.layer.4.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.4.attention.output.dense.weight',
#               tensor([[-0.0592, -0.0472,  0.0669,  ..., -0.0641, -0.0314, -0.0387],
#                       [ 0.0558,  0.0529,  0.0057,  ..., -0.0689, -0.0699,  0.0309],
#                       [ 0.0091, -0.0817,  0.1057,  ...,  0.0490,  0.0653,  0.0826],
#                       ...,
#                       [ 0.0711,  0.0915,  0.0420,  ..., -0.0890,  0.1733,  0.0849],
#                       [-0.1381,  0.0596,  0.0161,  ..., -0.0005,  0.1360, -0.0155],
#                       [-0.1219, -0.0069,  0.0453,  ...,  0.0786, -0.0746, -0.1355]])),
#              ('model.encoder.layer.4.attention.output.dense.bias',
#               tensor([-0.0181,  0.0413,  0.0193,  ..., -0.0028, -0.0074, -0.0034])),
#              ('model.encoder.layer.4.attention.LayerNorm.weight',
#               tensor([0.2609, 0.2442, 0.2076,  ..., 0.2426, 0.2558, 0.2091])),
#              ('model.encoder.layer.4.attention.LayerNorm.bias',
#               tensor([-0.0166, -0.0065, -0.0350,  ...,  0.0047, -0.0026, -0.0039])),
#              ('model.encoder.layer.4.intermediate.dense.weight',
#               tensor([[-0.1299,  0.0830,  0.1330,  ...,  0.1032, -0.1344, -0.0131],
#                       [ 0.0480,  0.1607, -0.1793,  ..., -0.1340, -0.0780, -0.1013],
#                       [ 0.1324, -0.0036, -0.0483,  ..., -0.1091, -0.1395,  0.0246],
#                       ...,
#                       [ 0.0203, -0.0034, -0.0692,  ..., -0.0548,  0.0372, -0.0577],
#                       [ 0.0837,  0.0274, -0.0299,  ..., -0.0401,  0.0090, -0.1249],
#                       [ 0.0466,  0.0071,  0.0079,  ..., -0.0494, -0.1189,  0.0683]])),
#              ('model.encoder.layer.4.intermediate.dense.bias',
#               tensor([-0.0537, -0.0212, -0.0530,  ..., -0.0363, -0.0996, -0.0489])),
#              ('model.encoder.layer.4.output.dense.weight',
#               tensor([[-0.0850,  0.0040,  0.0624,  ..., -0.1011,  0.0431, -0.0883],
#                       [ 0.0508,  0.2038,  0.1072,  ...,  0.0881, -0.1485,  0.0124],
#                       [ 0.0514, -0.0422, -0.0499,  ...,  0.0269,  0.0581,  0.1143],
#                       ...,
#                       [-0.0422, -0.0448, -0.0177,  ...,  0.0176, -0.0132,  0.0498],
#                       [-0.0242,  0.0064, -0.0465,  ..., -0.0834, -0.0007, -0.1095],
#                       [-0.0159, -0.0229,  0.0967,  ...,  0.0455,  0.0295,  0.1233]])),
#              ('model.encoder.layer.4.output.dense.bias',
#               tensor([-0.0541,  0.0502,  0.0327,  ..., -0.0080, -0.0251, -0.0074])),
#              ('model.encoder.layer.4.LayerNorm.weight',
#               tensor([0.4678, 0.4216, 0.4272,  ..., 0.3996, 0.3742, 0.4577])),
#              ('model.encoder.layer.4.LayerNorm.bias',
#               tensor([ 0.0683, -0.0150, -0.0124,  ..., -0.0145,  0.0151,  0.0258])),
#              ('model.encoder.layer.5.attention.self.query.weight',
#               tensor([[ 0.0455,  0.0555,  0.0712,  ..., -0.1959, -0.0375, -0.1490],
#                       [ 0.1975, -0.0712,  0.0386,  ...,  0.1613, -0.1085,  0.0446],
#                       [ 0.0218,  0.1250, -0.0219,  ..., -0.0797,  0.0503, -0.2129],
#                       ...,
#                       [-0.0484, -0.1376,  0.0248,  ..., -0.0553, -0.0990, -0.0855],
#                       [ 0.0150, -0.0490, -0.1811,  ...,  0.0224, -0.0007,  0.0563],
#                       [-0.0036,  0.0828, -0.0898,  ...,  0.1123,  0.0905, -0.0453]])),
#              ('model.encoder.layer.5.attention.self.query.bias',
#               tensor([ 0.0666,  0.0104,  0.1503,  ..., -0.2053,  0.0442,  0.0092])),
#              ('model.encoder.layer.5.attention.self.key.weight',
#               tensor([[ 0.0606,  0.0772, -0.0746,  ..., -0.1176,  0.1012,  0.0053],
#                       [-0.0037, -0.0719, -0.0641,  ...,  0.0517,  0.1183, -0.0017],
#                       [ 0.0085, -0.0843,  0.0362,  ..., -0.0447, -0.0203, -0.0227],
#                       ...,
#                       [-0.0075,  0.0447,  0.0681,  ...,  0.2097, -0.0989, -0.0415],
#                       [ 0.0618, -0.0430,  0.0639,  ..., -0.0289, -0.0732, -0.1226],
#                       [ 0.1122, -0.0321, -0.1254,  ..., -0.0543,  0.0442,  0.0547]])),
#              ('model.encoder.layer.5.attention.self.key.bias',
#               tensor([ 0.0570,  0.0193,  0.1499,  ...,  0.1409, -0.0185, -0.0633])),
#              ('model.encoder.layer.5.attention.self.value.weight',
#               tensor([[-0.0208, -0.0998,  0.0617,  ...,  0.0194,  0.0211,  0.1439],
#                       [-0.0323,  0.0230,  0.0980,  ...,  0.0787, -0.1657, -0.0492],
#                       [-0.0462,  0.0597, -0.0038,  ..., -0.0242, -0.1241, -0.0296],
#                       ...,
#                       [ 0.0569,  0.0825,  0.0015,  ..., -0.1006,  0.0206, -0.0318],
#                       [-0.0440,  0.1352,  0.0078,  ...,  0.0677,  0.0242, -0.2635],
#                       [ 0.0784, -0.0047, -0.0498,  ...,  0.1350,  0.0964,  0.0451]])),
#              ('model.encoder.layer.5.attention.self.value.bias',
#               tensor([ 0.0074, -0.0009,  0.0087,  ...,  0.0077, -0.0084,  0.0016])),
#              ('model.encoder.layer.5.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.5.attention.output.dense.weight',
#               tensor([[-0.0339, -0.0373, -0.0480,  ..., -0.0885, -0.1754, -0.0185],
#                       [-0.0762, -0.0287, -0.0344,  ..., -0.0955, -0.0845, -0.0787],
#                       [-0.0660, -0.0781,  0.0441,  ...,  0.1119, -0.1814,  0.0516],
#                       ...,
#                       [ 0.0124,  0.0727,  0.0611,  ...,  0.0102, -0.2100, -0.1266],
#                       [ 0.0850,  0.1108, -0.0014,  ..., -0.1195, -0.2461, -0.0894],
#                       [-0.1396, -0.0775,  0.1415,  ...,  0.1297,  0.1086, -0.0280]])),
#              ('model.encoder.layer.5.attention.output.dense.bias',
#               tensor([-0.0305,  0.0192,  0.0194,  ..., -0.0177, -0.0158, -0.0099])),
#              ('model.encoder.layer.5.attention.LayerNorm.weight',
#               tensor([0.2872, 0.2382, 0.2132,  ..., 0.2199, 0.2777, 0.2571])),
#              ('model.encoder.layer.5.attention.LayerNorm.bias',
#               tensor([-0.0409,  0.0127, -0.0197,  ...,  0.0064, -0.0174, -0.0150])),
#              ('model.encoder.layer.5.intermediate.dense.weight',
#               tensor([[ 0.0789,  0.0644,  0.0116,  ..., -0.0999,  0.0276, -0.0275],
#                       [-0.0464, -0.1684,  0.0890,  ..., -0.1897, -0.1165, -0.0389],
#                       [-0.0382, -0.0481,  0.0021,  ...,  0.0425,  0.1884,  0.1145],
#                       ...,
#                       [-0.0373,  0.0017, -0.1130,  ...,  0.0102, -0.1236,  0.0256],
#                       [ 0.1155,  0.0599, -0.0981,  ..., -0.0551,  0.0475,  0.2018],
#                       [-0.2491,  0.0584, -0.0011,  ..., -0.0978, -0.1713, -0.0499]])),
#              ('model.encoder.layer.5.intermediate.dense.bias',
#               tensor([-0.0484, -0.0640, -0.0490,  ..., -0.1133, -0.0666, -0.0096])),
#              ('model.encoder.layer.5.output.dense.weight',
#               tensor([[-0.0537, -0.0063,  0.0074,  ..., -0.0829,  0.0797,  0.0035],
#                       [-0.0877, -0.1556,  0.0573,  ...,  0.0299, -0.0395, -0.1100],
#                       [-0.0333,  0.0414,  0.0958,  ..., -0.0088,  0.0173, -0.0418],
#                       ...,
#                       [-0.0089,  0.0032,  0.1905,  ..., -0.0065,  0.0386, -0.1697],
#                       [ 0.0572, -0.0666,  0.0653,  ...,  0.0723, -0.1240, -0.1401],
#                       [-0.1114,  0.0010,  0.0632,  ..., -0.0480,  0.0587,  0.0104]])),
#              ('model.encoder.layer.5.output.dense.bias',
#               tensor([-0.0166,  0.0032,  0.0376,  ..., -0.0261, -0.0395, -0.0107])),
#              ('model.encoder.layer.5.LayerNorm.weight',
#               tensor([0.4611, 0.4583, 0.4728,  ..., 0.4502, 0.3655, 0.4652])),
#              ('model.encoder.layer.5.LayerNorm.bias',
#               tensor([-0.0133,  0.0081,  0.0084,  ..., -0.0200,  0.0155, -0.0136])),
#              ('model.encoder.layer.6.attention.self.query.weight',
#               tensor([[ 0.0166, -0.0745,  0.0639,  ...,  0.0276, -0.0759, -0.0243],
#                       [ 0.0832,  0.0656, -0.0835,  ...,  0.1388, -0.0088,  0.0221],
#                       [-0.0056, -0.1302,  0.0206,  ..., -0.0237, -0.0314,  0.0277],
#                       ...,
#                       [-0.1727, -0.0336,  0.1190,  ...,  0.0201,  0.1013,  0.2397],
#                       [-0.0508,  0.0394, -0.0786,  ..., -0.0375,  0.0853,  0.0477],
#                       [ 0.0250, -0.0760,  0.0448,  ...,  0.0415,  0.0944, -0.1856]])),
#              ('model.encoder.layer.6.attention.self.query.bias',
#               tensor([ 0.0392,  0.0048, -0.0029,  ...,  0.2003, -0.6322,  0.0518])),
#              ('model.encoder.layer.6.attention.self.key.weight',
#               tensor([[-0.0054, -0.1159, -0.0081,  ..., -0.1346, -0.0315, -0.0089],
#                       [ 0.0360, -0.0715,  0.0568,  ...,  0.1320,  0.0088,  0.0759],
#                       [-0.0503, -0.0664,  0.0295,  ..., -0.0368, -0.0197, -0.0377],
#                       ...,
#                       [-0.2009, -0.1113,  0.0904,  ..., -0.1300, -0.1177,  0.1978],
#                       [ 0.0872, -0.0051,  0.2518,  ...,  0.0688,  0.2350, -0.0088],
#                       [-0.1664, -0.0386, -0.2061,  ...,  0.0653,  0.0264, -0.0034]])),
#              ('model.encoder.layer.6.attention.self.key.bias',
#               tensor([ 0.0241, -0.0124,  0.0237,  ...,  0.1646, -0.0786,  0.0748])),
#              ('model.encoder.layer.6.attention.self.value.weight',
#               tensor([[ 0.1344, -0.0379,  0.0594,  ...,  0.0668, -0.0634,  0.0854],
#                       [-0.0537, -0.1352, -0.0816,  ..., -0.0301,  0.0366,  0.0276],
#                       [ 0.0512,  0.0388, -0.0402,  ..., -0.1150, -0.0004, -0.0632],
#                       ...,
#                       [-0.0085,  0.0227, -0.0293,  ...,  0.0261,  0.0309, -0.0074],
#                       [ 0.0052,  0.0799,  0.1864,  ...,  0.0249,  0.0753,  0.1147],
#                       [-0.0577, -0.0385,  0.0851,  ..., -0.0447, -0.0537,  0.1140]])),
#              ('model.encoder.layer.6.attention.self.value.bias',
#               tensor([-0.0108,  0.0074, -0.0115,  ..., -0.0005, -0.0132,  0.0109])),
#              ('model.encoder.layer.6.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.6.attention.output.dense.weight',
#               tensor([[ 0.0103, -0.0017,  0.0464,  ..., -0.0845, -0.0148,  0.0463],
#                       [-0.0614, -0.0249,  0.0786,  ...,  0.0377, -0.0229,  0.0605],
#                       [-0.0484,  0.1840, -0.0143,  ...,  0.1965,  0.0135, -0.0633],
#                       ...,
#                       [-0.0358,  0.0388, -0.1906,  ..., -0.0797, -0.0022, -0.0225],
#                       [-0.1550,  0.1810,  0.0503,  ...,  0.0006,  0.0136,  0.0226],
#                       [-0.0772,  0.0346, -0.0367,  ...,  0.0205,  0.1455, -0.1615]])),
#              ('model.encoder.layer.6.attention.output.dense.bias',
#               tensor([-0.0357, -0.0005,  0.0357,  ..., -0.0020, -0.0046, -0.0198])),
#              ('model.encoder.layer.6.attention.LayerNorm.weight',
#               tensor([0.2779, 0.2678, 0.2412,  ..., 0.2612, 0.2821, 0.2674])),
#              ('model.encoder.layer.6.attention.LayerNorm.bias',
#               tensor([ 0.0126, -0.0014, -0.0424,  ..., -0.0152, -0.0569,  0.0008])),
#              ('model.encoder.layer.6.intermediate.dense.weight',
#               tensor([[-0.0527, -0.0969, -0.1129,  ..., -0.0935, -0.0956, -0.0887],
#                       [-0.0104,  0.0500,  0.0719,  ...,  0.0343, -0.1014,  0.0678],
#                       [ 0.0795,  0.0843, -0.1291,  ..., -0.0027,  0.0208,  0.0713],
#                       ...,
#                       [ 0.0157,  0.0690, -0.0441,  ...,  0.0148,  0.0558, -0.1076],
#                       [-0.0321,  0.0931, -0.0292,  ..., -0.1453, -0.0454, -0.0377],
#                       [-0.0564,  0.1448,  0.0357,  ..., -0.1409, -0.0919, -0.0230]])),
#              ('model.encoder.layer.6.intermediate.dense.bias',
#               tensor([-0.0938, -0.0876, -0.0701,  ..., -0.0843, -0.0604, -0.0474])),
#              ('model.encoder.layer.6.output.dense.weight',
#               tensor([[-0.0717, -0.0075,  0.0409,  ..., -0.0881,  0.0263,  0.1551],
#                       [ 0.0245,  0.0357, -0.0578,  ...,  0.0107,  0.0630,  0.0566],
#                       [ 0.0597,  0.1302,  0.0416,  ...,  0.0705, -0.1108,  0.0127],
#                       ...,
#                       [ 0.0036,  0.0685, -0.0387,  ...,  0.0074, -0.2184,  0.0140],
#                       [-0.0245, -0.0170, -0.0393,  ...,  0.0302, -0.0119,  0.0452],
#                       [-0.0545,  0.0192,  0.0449,  ...,  0.0187,  0.1096, -0.0256]])),
#              ('model.encoder.layer.6.output.dense.bias',
#               tensor([-0.0109, -0.0267,  0.0374,  ..., -0.0027, -0.0736, -0.0006])),
#              ('model.encoder.layer.6.LayerNorm.weight',
#               tensor([0.4637, 0.4630, 0.4996,  ..., 0.4546, 0.4267, 0.4622])),
#              ('model.encoder.layer.6.LayerNorm.bias',
#               tensor([ 0.0300, -0.0275,  0.0784,  ..., -0.0217,  0.0858, -0.0093])),
#              ('model.encoder.layer.7.attention.self.query.weight',
#               tensor([[-0.0303,  0.0378,  0.0831,  ...,  0.0776, -0.0322, -0.0343],
#                       [-0.0611,  0.1275,  0.0070,  ..., -0.1232,  0.0432,  0.1255],
#                       [ 0.1045, -0.0407, -0.0409,  ..., -0.1120, -0.1226, -0.0593],
#                       ...,
#                       [-0.0827, -0.0546,  0.0564,  ...,  0.0182, -0.1618, -0.0087],
#                       [ 0.0690,  0.1016,  0.0913,  ...,  0.1653, -0.0266,  0.0851],
#                       [-0.0733, -0.0528, -0.0924,  ...,  0.0231,  0.2575,  0.0716]])),
#              ('model.encoder.layer.7.attention.self.query.bias',
#               tensor([ 0.1072, -0.0221, -0.0923,  ..., -0.1034, -0.0307,  0.0494])),
#              ('model.encoder.layer.7.attention.self.key.weight',
#               tensor([[-0.0829, -0.0164,  0.0175,  ...,  0.0364, -0.1260,  0.0099],
#                       [ 0.0072,  0.0216,  0.1653,  ..., -0.0946, -0.0365, -0.0147],
#                       [ 0.1015,  0.0211,  0.1346,  ..., -0.0571,  0.0151,  0.0439],
#                       ...,
#                       [ 0.0091,  0.0078,  0.0274,  ..., -0.0104, -0.1622, -0.0489],
#                       [ 0.1160, -0.0865,  0.0764,  ...,  0.2678, -0.1385,  0.0573],
#                       [ 0.1395,  0.0960,  0.1894,  ...,  0.0288,  0.0012,  0.0668]])),
#              ('model.encoder.layer.7.attention.self.key.bias',
#               tensor([-0.0407,  0.0354,  0.0204,  ..., -0.0649,  0.0901,  0.0745])),
#              ('model.encoder.layer.7.attention.self.value.weight',
#               tensor([[ 0.0800, -0.0242, -0.0416,  ..., -0.1304, -0.0063,  0.0173],
#                       [-0.0762, -0.1028, -0.1066,  ...,  0.1581,  0.0291,  0.0784],
#                       [ 0.0398, -0.0893, -0.0670,  ...,  0.0464,  0.1273,  0.0430],
#                       ...,
#                       [-0.0619,  0.1209,  0.0832,  ...,  0.0450, -0.0222, -0.2200],
#                       [-0.0837, -0.1236, -0.0058,  ...,  0.0200,  0.0282,  0.0403],
#                       [-0.0192,  0.0248, -0.0252,  ..., -0.1222,  0.0710, -0.1108]])),
#              ('model.encoder.layer.7.attention.self.value.bias',
#               tensor([ 0.0101,  0.0004,  0.0020,  ...,  0.0037, -0.0170,  0.0060])),
#              ('model.encoder.layer.7.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.7.attention.output.dense.weight',
#               tensor([[-0.0362, -0.0301,  0.0190,  ..., -0.0504,  0.0886,  0.0546],
#                       [-0.0113, -0.0288,  0.1803,  ..., -0.1407,  0.0486, -0.0037],
#                       [ 0.1165,  0.1628,  0.0357,  ..., -0.2204, -0.0589, -0.0718],
#                       ...,
#                       [ 0.0797, -0.1249, -0.0443,  ..., -0.0043, -0.0430,  0.0318],
#                       [-0.0327,  0.0261, -0.0966,  ..., -0.0412, -0.0540,  0.0203],
#                       [ 0.0651, -0.0642, -0.1570,  ...,  0.1873, -0.0146,  0.2062]])),
#              ('model.encoder.layer.7.attention.output.dense.bias',
#               tensor([-0.0142, -0.0201, -0.0009,  ..., -0.0034, -0.0254, -0.0255])),
#              ('model.encoder.layer.7.attention.LayerNorm.weight',
#               tensor([0.3043, 0.2763, 0.2597,  ..., 0.3063, 0.3059, 0.2805])),
#              ('model.encoder.layer.7.attention.LayerNorm.bias',
#               tensor([-0.0396, -0.0351, -0.0284,  ...,  0.0223, -0.0961,  0.0205])),
#              ('model.encoder.layer.7.intermediate.dense.weight',
#               tensor([[ 0.1594, -0.0514,  0.0073,  ...,  0.1420, -0.1593,  0.0534],
#                       [-0.1078, -0.1054, -0.0859,  ...,  0.0764, -0.0124,  0.1207],
#                       [ 0.0776,  0.0490, -0.1242,  ...,  0.0186,  0.0162, -0.0386],
#                       ...,
#                       [ 0.0187, -0.0599,  0.0059,  ..., -0.0299,  0.0818, -0.0233],
#                       [-0.0898, -0.0879, -0.1600,  ..., -0.0811, -0.0227, -0.0677],
#                       [-0.0189,  0.0419, -0.0165,  ...,  0.1051, -0.1314,  0.1589]])),
#              ('model.encoder.layer.7.intermediate.dense.bias',
#               tensor([-0.0432, -0.0296, -0.0645,  ..., -0.0717, -0.0852, -0.0497])),
#              ('model.encoder.layer.7.output.dense.weight',
#               tensor([[ 0.0089,  0.0253,  0.0889,  ...,  0.1006, -0.0067,  0.0567],
#                       [-0.0438,  0.1110, -0.0298,  ..., -0.1902, -0.1567, -0.0087],
#                       [-0.1014,  0.0276,  0.0026,  ...,  0.0934, -0.0713, -0.0394],
#                       ...,
#                       [ 0.0128, -0.0853,  0.0124,  ...,  0.0037, -0.1031, -0.0568],
#                       [-0.0525, -0.0426, -0.0546,  ...,  0.0473,  0.0138,  0.0558],
#                       [ 0.0709, -0.1689, -0.0085,  ..., -0.0399, -0.1608,  0.0984]])),
#              ('model.encoder.layer.7.output.dense.bias',
#               tensor([ 0.0150, -0.0489, -0.0044,  ..., -0.0287, -0.0408, -0.0236])),
#              ('model.encoder.layer.7.LayerNorm.weight',
#               tensor([0.4391, 0.4534, 0.4459,  ..., 0.4552, 0.4108, 0.4541])),
#              ('model.encoder.layer.7.LayerNorm.bias',
#               tensor([-0.0094, -0.0155,  0.0671,  ...,  0.0037, -0.0005,  0.0141])),
#              ('model.encoder.layer.8.attention.self.query.weight',
#               tensor([[-0.0550, -0.0654,  0.0052,  ..., -0.0748, -0.0288,  0.1110],
#                       [ 0.0096,  0.0098,  0.0137,  ..., -0.1044, -0.0668, -0.1095],
#                       [-0.0250, -0.0157,  0.0418,  ..., -0.0827,  0.0650, -0.0030],
#                       ...,
# ...
#              ('model.encoder.layer.32.attention.output.dense.weight',
#               tensor([[-0.0614, -0.1771,  0.0279,  ..., -0.0396, -0.0322,  0.1966],
#                       [ 0.2179,  0.1164, -0.1050,  ...,  0.2445, -0.2348, -0.0708],
#                       [ 0.0559,  0.0394, -0.0432,  ...,  0.1234,  0.0110, -0.1421],
#                       ...,
#                       [-0.0740, -0.0175, -0.0417,  ..., -0.0130, -0.2168,  0.0207],
#                       [-0.0224, -0.0793,  0.0599,  ...,  0.0274,  0.1019, -0.0053],
#                       [-0.2617,  0.0817, -0.0151,  ..., -0.0537, -0.0210,  0.3694]])),
#              ('model.encoder.layer.32.attention.output.dense.bias',
#               tensor([ 0.0904, -0.0586, -0.0612,  ..., -0.1166, -0.0725, -0.0572])),
#              ('model.encoder.layer.32.attention.LayerNorm.weight',
#               tensor([0.4143, 0.3937, 0.3954,  ..., 0.3517, 0.3678, 0.4025])),
#              ('model.encoder.layer.32.attention.LayerNorm.bias',
#               tensor([-0.0359,  0.0498,  0.0188,  ...,  0.0074,  0.0125,  0.0124])),
#              ('model.encoder.layer.32.intermediate.dense.weight',
#               tensor([[-0.0176, -0.0484, -0.0921,  ..., -0.1180,  0.0788, -0.0024],
#                       [-0.0418,  0.0200,  0.1550,  ..., -0.1677,  0.0256, -0.0682],
#                       [-0.0057, -0.0935,  0.0007,  ..., -0.1467,  0.0847, -0.0794],
#                       ...,
#                       [-0.0352, -0.0485, -0.0103,  ...,  0.0478, -0.0007,  0.0059],
#                       [-0.0813, -0.0617,  0.1352,  ...,  0.2700, -0.0622,  0.0304],
#                       [-0.0969,  0.1109, -0.0504,  ...,  0.0110,  0.0433, -0.0930]])),
#              ('model.encoder.layer.32.intermediate.dense.bias',
#               tensor([-0.0063, -0.0173, -0.0491,  ..., -0.0267, -0.0112, -0.0281])),
#              ('model.encoder.layer.32.output.dense.weight',
#               tensor([[ 2.6094e-02, -1.7358e-01,  6.3305e-02,  ...,  2.7059e-01,
#                        -3.7522e-01, -1.9531e-02],
#                       [-9.4935e-02, -1.6791e-01,  3.8845e-02,  ...,  1.7679e-01,
#                        -1.0533e-01,  8.9886e-03],
#                       [ 1.1556e-01, -1.1059e-02,  5.5905e-02,  ...,  2.1250e-01,
#                         3.1155e-01,  3.7527e-01],
#                       ...,
#                       [ 1.0349e-01,  7.6079e-02,  6.6433e-02,  ...,  2.6062e-01,
#                         4.9161e-02,  5.4206e-02],
#                       [-1.4037e-01, -7.6610e-02, -5.7396e-03,  ..., -1.5949e-01,
#                        -7.1658e-02,  1.3921e-01],
#                       [-2.4807e-02,  1.0781e-04, -1.1837e-01,  ..., -1.0654e-01,
#                        -2.1641e-02, -1.0887e-01]])),
#              ('model.encoder.layer.32.output.dense.bias',
#               tensor([ 0.0156, -0.0045, -0.0523,  ..., -0.0713, -0.0617,  0.0440])),
#              ('model.encoder.layer.32.LayerNorm.weight',
#               tensor([0.4608, 0.5144, 0.4786,  ..., 0.4624, 0.4464, 0.4801])),
#              ('model.encoder.layer.32.LayerNorm.bias',
#               tensor([ 0.0034, -0.0434, -0.0029,  ..., -0.0273,  0.0035, -0.0713])),
#              ('model.encoder.emb_layer_norm_after.weight',
#               tensor([0.2352, 0.2603, 0.2513,  ..., 0.2622, 0.2562, 0.2590])),
#              ('model.encoder.emb_layer_norm_after.bias',
#               tensor([-0.0155,  0.0092,  0.0213,  ..., -0.0537,  0.0132,  0.0790])),
#              ('model.pooler.dense.weight',
#               tensor([[ 0.0385,  0.0297,  0.0180,  ..., -0.0023, -0.0126, -0.0253],
#                       [-0.0059, -0.0056,  0.0217,  ..., -0.0335, -0.0389,  0.0020],
#                       [-0.0135, -0.0378, -0.0368,  ..., -0.0310, -0.0286,  0.0041],
#                       ...,
#                       [-0.0016,  0.0117, -0.0140,  ..., -0.0081, -0.0281,  0.0021],
#                       [-0.0125, -0.0080, -0.0207,  ..., -0.0027, -0.0050, -0.0137],
#                       [-0.0449, -0.0260, -0.0030,  ..., -0.0031,  0.0018,  0.0077]])),
#              ('model.pooler.dense.bias',
#               tensor([0., 0., 0.,  ..., 0., 0., 0.])),
#              ('model.contact_head.regression.weight',
#               tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  8.6607e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.9052e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  8.7018e-02,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.4382e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.1634e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.6754e-01,  0.0000e+00,
#                         0.0000e+00,  4.7571e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  1.8241e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  6.3387e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.1099e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.4932e-01, -2.0187e-02,
#                         1.0717e-01,  0.0000e+00,  1.2029e+00,  0.0000e+00,  0.0000e+00,
#                         1.4237e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  7.7550e-01,
#                         2.2187e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  5.7300e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         6.0197e+00,  0.0000e+00,  1.4587e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -1.6267e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.7784e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -3.6329e-02,  2.2149e-01,  0.0000e+00, -1.3990e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -8.3230e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -4.3948e+00,  0.0000e+00, -7.4849e-02, -6.5220e-01,  0.0000e+00,
#                        -2.4335e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1386e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -1.1154e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.7978e-01,  0.0000e+00,  0.0000e+00,
#                        -6.7810e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -2.7959e-01,  0.0000e+00,  1.3830e+00,
#                         0.0000e+00,  7.7892e-01,  0.0000e+00,  0.0000e+00, -9.2584e-01,
#                         5.4742e-03,  0.0000e+00, -8.9198e-02,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -3.0531e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  7.6630e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  5.1623e-01,  2.0175e+00,
#                         8.5277e-02,  0.0000e+00,  0.0000e+00, -3.6948e-01,  0.0000e+00,
#                         0.0000e+00,  6.8948e-02,  0.0000e+00,  0.0000e+00, -7.2590e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  2.9609e-01,  0.0000e+00,
#                        -1.5232e+00,  0.0000e+00,  0.0000e+00,  4.2038e-01,  0.0000e+00,
#                         1.2211e+00,  0.0000e+00,  0.0000e+00,  2.9299e+00, -2.1506e+00,
#                         0.0000e+00,  9.2984e-01,  7.6042e-01, -3.5253e-01,  0.0000e+00,
#                        -1.2273e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -8.9307e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  1.0350e-01,  1.7648e-01, -4.1064e-01,  0.0000e+00,
#                        -3.7447e-01,  0.0000e+00,  1.5040e-01,  0.0000e+00,  9.9286e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  7.7144e-02,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         4.4486e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.7663e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.5656e-02,  3.7187e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -6.7643e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -2.8274e-01,
#                         0.0000e+00,  0.0000e+00, -2.2929e-01,  0.0000e+00,  0.0000e+00,
#                         9.4702e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -2.2373e-01,
#                         1.6001e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         1.5397e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  4.1931e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.3743e+00, -6.7316e-03,  0.0000e+00,  9.6804e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -8.7255e-02,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.4948e-01,  0.0000e+00, -1.4712e-02,
#                         4.6000e-01,  0.0000e+00,  0.0000e+00, -1.2773e-01,  5.4927e-01,
#                         0.0000e+00,  1.1131e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         8.0312e-01,  0.0000e+00,  0.0000e+00,  3.2332e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  8.0039e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.5197e+00,  0.0000e+00,
#                         0.0000e+00, -1.2544e-01,  0.0000e+00,  0.0000e+00,  9.4995e-01,
#                         4.1188e-01,  0.0000e+00,  0.0000e+00, -1.4186e+00,  0.0000e+00,
#                         0.0000e+00,  2.2519e-01, -1.3035e+00, -3.3026e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         2.9643e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.2301e+00,  5.8397e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.8739e-01,  0.0000e+00,
#                         0.0000e+00,  1.0099e+00,  0.0000e+00, -1.1772e+00,  0.0000e+00,
#                         0.0000e+00, -1.1987e-01,  1.9504e+00,  0.0000e+00,  0.0000e+00,
#                         4.8955e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.4301e+00,
#                         1.1284e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -1.4012e+00,  0.0000e+00,  3.8097e-01,  1.5137e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.5034e+00,  4.3518e-02,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         3.7862e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  6.7905e-01,  0.0000e+00, -3.4386e+00,
#                         0.0000e+00, -1.4802e-01, -3.9989e-01,  1.4289e-02,  0.0000e+00,
#                         2.6872e+00,  1.6644e+00,  0.0000e+00,  1.7983e+00,  0.0000e+00,
#                         1.5690e+00,  4.3481e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  2.6579e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  2.0364e+00,  0.0000e+00,  0.0000e+00,  1.0977e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.4038e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         1.2369e+00,  0.0000e+00,  2.5634e+00,  0.0000e+00,  0.0000e+00,
#                         4.7633e+00,  0.0000e+00,  0.0000e+00,  3.5985e+00,  2.0484e-01,
#                         0.0000e+00,  0.0000e+00,  1.1325e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  4.4427e+00,  1.9547e+00,  6.3678e+00,  3.4624e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0421e+01,  0.0000e+00]])),
#              ('model.contact_head.regression.bias', tensor([-4.9368])),
#              ('fc.weight',
#               tensor([[-0.0116,  0.0178,  0.0156,  ...,  0.0320,  0.0127, -0.0135]])),
#              ('fc.bias', tensor([-0.0002]))])

# %%
# !mkdir /home2/sagawa/PLTNUM/classification_automodel

# %%
config = AutoConfig.from_pretrained("facebook/esm2_t33_650M_UR50D")
config.save_pretrained("/home2/sagawa/PLTNUM/classification_automodel")
# save model
torch.save(model.state_dict(), "/home2/sagawa/PLTNUM/classification_automodel/pytorch_model.bin")

# %%
from transformers import PreTrainedModel, AutoConfig, AutoModel
import torch.nn as nn
class PLTNUM(PreTrainedModel):
    config_class = AutoConfig
    def __init__(self, config, cfg):
        super().__init__(config)
        self.cfg = cfg
        self.config = config
        self.model = AutoModel.from_pretrained(self.config._name_or_path)
        self.fc_dropout1 = nn.Dropout(0.8)
        self.fc_dropout2 = nn.Dropout(0.4 if cfg.task == "classification" else 0.8)
        self.fc_dropout2 = nn.Dropout(0.8)  
        self.fc = nn.Linear(self.config.hidden_size, 1)
        self._init_weights(self.fc)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.bias is not None:
                module.bias.data.zero_()
        elif isinstance(module, nn.Embedding):
            module.weight.data.normal_(mean=0.0, std=self.config.initializer_range)
            if module.padding_idx is not None:
                module.weight.data[module.padding_idx].zero_()
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)

    def forward(self, inputs):
        outputs = self.model(**inputs)
        last_hidden_states = outputs[0][:, 0]
        output = (
            self.fc(self.fc_dropout1(last_hidden_states))
            + self.fc(self.fc_dropout2(last_hidden_states))
        ) / 2
        return output

    def create_embedding(self, inputs):
        outputs = self.model(**inputs)
        last_hidden_states = outputs[0][:, 0]
        return last_hidden_states

# %%
model = PLTNUM.from_pretrained("facebook/esm2_t33_650M_UR50D")

# %%
model = PLTNUM.from_pretrained("/home2/sagawa/PLTNUM/classification_automodel", cfg)
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at /home2/sagawa/PLTNUM/classification_automodel and are newly initialized: ['contact_head.regression.bias', 'contact_head.regression.weight', 'embeddings.position_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.emb_layer_norm_after.bias', 'encoder.emb_layer_norm_after.weight', 'encoder.layer.0.LayerNorm.bias', 'encoder.layer.0.LayerNorm.weight', 'encoder.layer.0.attention.LayerNorm.bias', 'encoder.layer.0.attention.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.LayerNorm.bias', 'encoder.layer.1.LayerNorm.weight', 'encoder.layer.1.attention.LayerNorm.bias', 'encoder.layer.1.attention.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.LayerNorm.bias', 'encoder.layer.10.LayerNorm.weight', 'encoder.layer.10.attention.LayerNorm.bias', 'encoder.layer.10.attention.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.LayerNorm.bias', 'encoder.layer.11.LayerNorm.weight', 'encoder.layer.11.attention.LayerNorm.bias', 'encoder.layer.11.attention.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.12.LayerNorm.bias', 'encoder.layer.12.LayerNorm.weight', 'encoder.layer.12.attention.LayerNorm.bias', 'encoder.layer.12.attention.LayerNorm.weight', 'encoder.layer.12.attention.output.dense.bias', 'encoder.layer.12.attention.output.dense.weight', 'encoder.layer.12.attention.self.key.bias', 'encoder.layer.12.attention.self.key.weight', 'encoder.layer.12.attention.self.query.bias', 'encoder.layer.12.attention.self.query.weight', 'encoder.layer.12.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.12.attention.self.value.bias', 'encoder.layer.12.attention.sel ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.state_dict()
# Out:
# OrderedDict([('model.embeddings.word_embeddings.weight',
#               tensor([[ 0.0540, -0.0574, -0.1302,  ..., -0.2233,  0.1189, -0.0651],
#                       [ 0.0614,  0.0292, -0.1028,  ..., -0.0330,  0.0668, -0.0575],
#                       [-0.0896, -0.0439, -0.0575,  ..., -0.0582,  0.0655, -0.1094],
#                       ...,
#                       [ 0.0023,  0.0143,  0.0514,  ..., -0.0193,  0.0112,  0.0053],
#                       [ 0.0731,  0.0470,  0.0346,  ...,  0.1118,  0.0465, -0.0243],
#                       [ 0.0492,  0.0254, -0.1112,  ..., -0.0257,  0.0599, -0.0614]])),
#              ('model.embeddings.position_embeddings.weight',
#               tensor([[ 0.0026,  0.0083,  0.0133,  ..., -0.0090,  0.0321,  0.0109],
#                       [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#                       [ 0.0140,  0.0045,  0.0005,  ...,  0.0225, -0.0110, -0.0185],
#                       ...,
#                       [ 0.0315,  0.0066, -0.0124,  ..., -0.0021, -0.0198,  0.0023],
#                       [ 0.0121,  0.0167,  0.0021,  ...,  0.0187, -0.0207, -0.0138],
#                       [ 0.0053,  0.0031,  0.0104,  ..., -0.0176, -0.0125,  0.0156]])),
#              ('model.encoder.layer.0.attention.self.query.weight',
#               tensor([[-0.0010,  0.0720, -0.0222,  ...,  0.0224,  0.0110, -0.0049],
#                       [ 0.0101, -0.0189, -0.0463,  ..., -0.0124,  0.0128,  0.0216],
#                       [-0.0039,  0.0036, -0.0530,  ...,  0.0401,  0.0003,  0.0037],
#                       ...,
#                       [-0.0082, -0.0037,  0.0052,  ...,  0.0121, -0.0035,  0.0119],
#                       [-0.0124, -0.0508, -0.1796,  ...,  0.0419, -0.0225,  0.0115],
#                       [ 0.0098,  0.0079, -0.0162,  ..., -0.0121, -0.0109, -0.0007]])),
#              ('model.encoder.layer.0.attention.self.query.bias',
#               tensor([ 0.0158,  0.0173,  0.0124,  ..., -0.0082,  0.5690,  0.0067])),
#              ('model.encoder.layer.0.attention.self.key.weight',
#               tensor([[-0.0154,  0.0167,  0.0126,  ...,  0.0096,  0.0017, -0.0173],
#                       [-0.0017, -0.0210,  0.0465,  ..., -0.0354,  0.0132,  0.0205],
#                       [-0.0053,  0.0444, -0.0267,  ..., -0.0385, -0.0087, -0.0227],
#                       ...,
#                       [-0.0137,  0.0128, -0.0014,  ...,  0.0203,  0.0037, -0.0168],
#                       [ 0.0145, -0.1591, -0.0610,  ..., -0.1398,  0.0040, -0.0051],
#                       [-0.0059, -0.0007,  0.0052,  ..., -0.0299, -0.0098, -0.0081]])),
#              ('model.encoder.layer.0.attention.self.key.bias',
#               tensor([ 0.0148, -0.0152,  0.0210,  ..., -0.0212, -0.0140, -0.0027])),
#              ('model.encoder.layer.0.attention.self.value.weight',
#               tensor([[-0.0126,  0.0043, -0.0156,  ...,  0.0052,  0.0156,  0.0156],
#                       [-0.0007,  0.1000, -0.0322,  ...,  0.0865,  0.0335,  0.0076],
#                       [ 0.0114,  0.0033, -0.0154,  ...,  0.0089, -0.0120, -0.0087],
#                       ...,
#                       [ 0.0233, -0.0097,  0.0137,  ...,  0.0098,  0.0254,  0.0019],
#                       [-0.0210,  0.0273, -0.0101,  ...,  0.0137,  0.0028,  0.0096],
#                       [ 0.0045,  0.0174, -0.0039,  ..., -0.0121,  0.0376,  0.0113]])),
#              ('model.encoder.layer.0.attention.self.value.bias',
#               tensor([-0.0109,  0.0282, -0.0008,  ..., -0.0077, -0.0314, -0.0105])),
#              ('model.encoder.layer.0.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.0.attention.output.dense.weight',
#               tensor([[-2.2805e-02, -4.2929e-02,  3.5805e-02,  ...,  8.4162e-03,
#                         5.8222e-02, -3.6890e-02],
#                       [ 5.8070e-02, -6.7157e-02, -1.7512e-02,  ..., -1.6311e-02,
#                         1.6970e-04, -1.0420e-01],
#                       [-1.2629e-02, -2.4866e-03,  1.5781e-02,  ..., -3.0989e-02,
#                         5.4859e-02, -3.5524e-02],
#                       ...,
#                       [-2.4611e-02, -1.7284e-02,  2.1919e-02,  ...,  6.8041e-02,
#                        -3.7192e-02, -3.2710e-02],
#                       [-1.1521e-02,  3.1871e-02, -2.9001e-02,  ...,  8.1517e-03,
#                        -5.4071e-05,  1.6370e-02],
#                       [ 1.5459e-02, -3.0153e-02, -6.2363e-03,  ...,  3.1608e-02,
#                         4.5019e-02,  1.0971e-02]])),
#              ('model.encoder.layer.0.attention.output.dense.bias',
#               tensor([ 0.0618, -0.0080,  0.0038,  ...,  0.0203, -0.0234, -0.0107])),
#              ('model.encoder.layer.0.attention.LayerNorm.weight',
#               tensor([ 0.0003,  0.0513,  0.0894,  ...,  0.0083, -0.0003,  0.0002])),
#              ('model.encoder.layer.0.attention.LayerNorm.bias',
#               tensor([ 1.1234e-03, -5.8691e-03,  1.1424e-02,  ..., -2.0222e-03,
#                       -2.0548e-05,  7.2370e-05])),
#              ('model.encoder.layer.0.intermediate.dense.weight',
#               tensor([[-0.0250,  0.0467, -0.0283,  ..., -0.0459, -0.0177, -0.0341],
#                       [-0.0889, -0.0306, -0.0114,  ..., -0.0164,  0.0369,  0.0213],
#                       [-0.0357,  0.0157,  0.0743,  ...,  0.0540,  0.1045, -0.1139],
#                       ...,
#                       [-0.0237,  0.0449,  0.0116,  ..., -0.0567,  0.0111, -0.0478],
#                       [-0.0061,  0.0502,  0.2140,  ..., -0.1098, -0.0912, -0.0449],
#                       [-0.0639, -0.1005, -0.0145,  ..., -0.1149, -0.1136, -0.0415]])),
#              ('model.encoder.layer.0.intermediate.dense.bias',
#               tensor([ 0.0556,  0.0409, -0.0082,  ...,  0.0081, -0.0119, -0.0193])),
#              ('model.encoder.layer.0.output.dense.weight',
#               tensor([[-0.0525, -0.1686, -0.0057,  ..., -0.0054,  0.0716,  0.0349],
#                       [ 0.1015,  0.1539,  0.1187,  ...,  0.0285,  0.0221, -0.0948],
#                       [-0.0638,  0.0428, -0.0321,  ..., -0.0210,  0.0930,  0.0721],
#                       ...,
#                       [-0.0094, -0.1809, -0.0465,  ..., -0.0037, -0.0753,  0.0155],
#                       [-0.0220,  0.0043, -0.0541,  ...,  0.0166, -0.0426, -0.0805],
#                       [-0.0228, -0.1844, -0.0276,  ..., -0.0174,  0.0015,  0.0259]])),
#              ('model.encoder.layer.0.output.dense.bias',
#               tensor([ 0.0231,  0.0007,  0.0468,  ..., -0.0660, -0.0250, -0.0328])),
#              ('model.encoder.layer.0.LayerNorm.weight',
#               tensor([0.2630, 0.3665, 0.0661,  ..., 0.0614, 0.0767, 0.0778])),
#              ('model.encoder.layer.0.LayerNorm.bias',
#               tensor([ 0.0388, -0.0270, -0.0656,  ...,  0.0933,  0.0705,  0.0792])),
#              ('model.encoder.layer.1.attention.self.query.weight',
#               tensor([[ 0.0376,  0.0007, -0.0093,  ..., -0.0278,  0.2951, -0.1014],
#                       [-0.0005, -0.1403, -0.0344,  ..., -0.0024, -0.0063,  0.0285],
#                       [ 0.2168,  0.0299,  0.0124,  ..., -0.0326,  0.0743, -0.0987],
#                       ...,
#                       [ 0.0496, -0.0521,  0.0120,  ..., -0.0025,  0.0984,  0.0396],
#                       [ 0.1589, -0.0062,  0.0706,  ..., -0.0069,  0.1702, -0.0630],
#                       [ 0.1325, -0.0207,  0.1199,  ...,  0.0346,  0.0186, -0.0015]])),
#              ('model.encoder.layer.1.attention.self.query.bias',
#               tensor([ 0.1207, -0.0511, -0.0469,  ..., -0.0065,  0.0014, -0.0083])),
#              ('model.encoder.layer.1.attention.self.key.weight',
#               tensor([[-0.1743,  0.0147,  0.1155,  ...,  0.0137, -0.0850,  0.0005],
#                       [ 0.0911, -0.0453,  0.0692,  ...,  0.0655,  0.0129,  0.0142],
#                       [-0.0400,  0.0603,  0.0201,  ...,  0.0621, -0.0935,  0.0020],
#                       ...,
#                       [ 0.0134, -0.0566, -0.0356,  ...,  0.0398, -0.0717, -0.1175],
#                       [-0.0210,  0.0552,  0.0622,  ..., -0.2123,  0.0185, -0.0349],
#                       [ 0.0602,  0.0547, -0.0663,  ..., -0.0971, -0.0385, -0.0415]])),
#              ('model.encoder.layer.1.attention.self.key.bias',
#               tensor([-0.0877,  0.0807,  0.0499,  ..., -0.0507, -0.0967, -0.0005])),
#              ('model.encoder.layer.1.attention.self.value.weight',
#               tensor([[ 0.0529, -0.0170, -0.0262,  ...,  0.0165, -0.0894, -0.0209],
#                       [-0.0359,  0.0150, -0.0110,  ..., -0.1097, -0.0742,  0.0734],
#                       [ 0.0065, -0.0657,  0.0476,  ...,  0.0272,  0.0230,  0.0107],
#                       ...,
#                       [-0.0059, -0.0662,  0.0105,  ...,  0.0727, -0.1176,  0.0191],
#                       [ 0.0090,  0.1124, -0.0749,  ...,  0.0538, -0.0314, -0.0683],
#                       [ 0.0404,  0.0339,  0.0533,  ...,  0.0195, -0.0305, -0.0960]])),
#              ('model.encoder.layer.1.attention.self.value.bias',
#               tensor([ 0.0030,  0.0104,  0.0001,  ..., -0.0016,  0.0220,  0.0068])),
#              ('model.encoder.layer.1.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.1.attention.output.dense.weight',
#               tensor([[-0.0003,  0.0335, -0.0065,  ...,  0.0454,  0.0525,  0.0147],
#                       [-0.0309,  0.0197,  0.0567,  ...,  0.0631,  0.0055, -0.0548],
#                       [ 0.0148,  0.0185,  0.0666,  ...,  0.0112, -0.0061, -0.0757],
#                       ...,
#                       [-0.0767,  0.0111, -0.0824,  ...,  0.0111, -0.1390,  0.0347],
#                       [-0.0819, -0.0272, -0.0476,  ...,  0.0294,  0.1894,  0.0354],
#                       [-0.0267, -0.0540, -0.0727,  ..., -0.0057,  0.0127,  0.0824]])),
#              ('model.encoder.layer.1.attention.output.dense.bias',
#               tensor([ 0.0593, -0.0319,  0.0515,  ..., -0.0850, -0.0291, -0.0188])),
#              ('model.encoder.layer.1.attention.LayerNorm.weight',
#               tensor([0.1175, 0.0822, 0.0792,  ..., 0.1778, 0.1075, 0.1178])),
#              ('model.encoder.layer.1.attention.LayerNorm.bias',
#               tensor([-0.0488,  0.0316, -0.0203,  ...,  0.0536,  0.0234,  0.0053])),
#              ('model.encoder.layer.1.intermediate.dense.weight',
#               tensor([[-3.0234e-02,  6.3647e-02, -2.3893e-02,  ..., -4.3580e-02,
#                        -2.1959e-02, -1.5514e-02],
#                       [-5.5472e-02, -1.0226e-01, -4.0204e-03,  ..., -1.8647e-01,
#                         1.0977e-01, -2.4295e-01],
#                       [-3.0110e-02,  2.5071e-02, -3.4869e-02,  ...,  2.6546e-02,
#                         2.6946e-02,  6.1301e-05],
#                       ...,
#                       [ 2.6203e-03, -1.1398e-02, -3.2700e-02,  ...,  2.0329e-02,
#                         1.0766e-02, -4.0275e-02],
#                       [-1.0147e-01, -2.8046e-02,  7.4162e-02,  ..., -1.4907e-01,
#                        -1.4753e-01,  1.7215e-01],
#                       [-1.8935e-02,  1.2513e-02, -3.6763e-02,  ..., -3.0627e-02,
#                        -3.0648e-03,  2.5642e-02]])),
#              ('model.encoder.layer.1.intermediate.dense.bias',
#               tensor([-0.1036, -0.0096, -0.0080,  ...,  0.0014, -0.0070, -0.1478])),
#              ('model.encoder.layer.1.output.dense.weight',
#               tensor([[ 0.0061, -0.1107, -0.0422,  ..., -0.0237,  0.0662,  0.0008],
#                       [ 0.0070,  0.0352,  0.0161,  ...,  0.0356, -0.1099,  0.0138],
#                       [-0.0090,  0.1258, -0.0161,  ..., -0.0112, -0.0244, -0.0067],
#                       ...,
#                       [ 0.0071, -0.0784,  0.0091,  ...,  0.0427, -0.0907, -0.0151],
#                       [-0.0116,  0.0556, -0.0366,  ..., -0.0542, -0.1338, -0.0015],
#                       [ 0.0026,  0.0843, -0.0083,  ..., -0.0562, -0.0165, -0.0011]])),
#              ('model.encoder.layer.1.output.dense.bias',
#               tensor([ 0.0003,  0.0619,  0.0502,  ..., -0.0892,  0.0059,  0.0128])),
#              ('model.encoder.layer.1.LayerNorm.weight',
#               tensor([0.4100, 0.4476, 0.3509,  ..., 0.3112, 0.2467, 0.2432])),
#              ('model.encoder.layer.1.LayerNorm.bias',
#               tensor([ 0.0902, -0.2198,  0.0312,  ..., -0.0071, -0.0963, -0.0486])),
#              ('model.encoder.layer.2.attention.self.query.weight',
#               tensor([[ 0.0431, -0.0233, -0.1518,  ...,  0.0420, -0.0709, -0.0021],
#                       [-0.0304, -0.0139, -0.2031,  ...,  0.0286, -0.1203,  0.0487],
#                       [-0.0238, -0.1383, -0.0711,  ...,  0.0059,  0.0206, -0.1622],
#                       ...,
#                       [ 0.0268, -0.0898, -0.1000,  ..., -0.0332, -0.0412, -0.2053],
#                       [-0.0623,  0.1836, -0.0075,  ..., -0.1741, -0.2626, -0.2706],
#                       [ 0.0003, -0.1742, -0.1804,  ..., -0.0091,  0.1203, -0.0640]])),
#              ('model.encoder.layer.2.attention.self.query.bias',
#               tensor([-0.0590, -0.0333,  0.0441,  ..., -0.0773, -0.0549, -0.0438])),
#              ('model.encoder.layer.2.attention.self.key.weight',
#               tensor([[-0.0358, -0.0519,  0.0442,  ...,  0.0645, -0.0524, -0.0889],
#                       [-0.0756, -0.0285,  0.0583,  ..., -0.0196,  0.1150,  0.0880],
#                       [ 0.0823,  0.1096, -0.1011,  ..., -0.0067, -0.1422,  0.0151],
#                       ...,
#                       [-0.0033, -0.3077, -0.1020,  ...,  0.1410, -0.0659, -0.0245],
#                       [ 0.0337,  0.0522,  0.0584,  ..., -0.0133, -0.0790,  0.0093],
#                       [-0.1243, -0.3026,  0.0702,  ...,  0.0415, -0.1655, -0.0230]])),
#              ('model.encoder.layer.2.attention.self.key.bias',
#               tensor([ 0.0124, -0.0391, -0.0358,  ...,  0.1092, -0.0354, -0.0022])),
#              ('model.encoder.layer.2.attention.self.value.weight',
#               tensor([[ 0.0888, -0.0030, -0.0259,  ..., -0.0384,  0.0289, -0.0208],
#                       [ 0.1227,  0.0009, -0.0666,  ..., -0.0621,  0.0723, -0.0005],
#                       [-0.0215, -0.0662,  0.0004,  ..., -0.0473, -0.0586,  0.0769],
#                       ...,
#                       [-0.1009, -0.1017, -0.0163,  ..., -0.2305, -0.1009, -0.0839],
#                       [-0.1140, -0.0410, -0.0304,  ..., -0.0396,  0.1272,  0.0513],
#                       [-0.0267, -0.0445,  0.0285,  ..., -0.0540, -0.1230, -0.0194]])),
#              ('model.encoder.layer.2.attention.self.value.bias',
#               tensor([ 0.0004,  0.0029,  0.0102,  ..., -0.0042, -0.0061, -0.0002])),
#              ('model.encoder.layer.2.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.2.attention.output.dense.weight',
#               tensor([[-0.1272, -0.0381,  0.1234,  ...,  0.0636,  0.0655, -0.0660],
#                       [ 0.0603,  0.0596,  0.1540,  ..., -0.0778, -0.1679,  0.0404],
#                       [-0.0569, -0.0010, -0.0938,  ...,  0.0358,  0.0304,  0.0102],
#                       ...,
#                       [ 0.0572,  0.0304, -0.0199,  ...,  0.1004,  0.0582,  0.0497],
#                       [-0.0278, -0.1403,  0.0050,  ...,  0.1719, -0.0763, -0.1441],
#                       [ 0.1154, -0.0355,  0.0172,  ...,  0.0253, -0.0325,  0.0836]])),
#              ('model.encoder.layer.2.attention.output.dense.bias',
#               tensor([ 0.0414,  0.0337,  0.0626,  ..., -0.0905, -0.0119,  0.0226])),
#              ('model.encoder.layer.2.attention.LayerNorm.weight',
#               tensor([0.1861, 0.1644, 0.1312,  ..., 0.2101, 0.1767, 0.1646])),
#              ('model.encoder.layer.2.attention.LayerNorm.bias',
#               tensor([-0.0627,  0.0243, -0.0444,  ...,  0.0395,  0.0192, -0.0109])),
#              ('model.encoder.layer.2.intermediate.dense.weight',
#               tensor([[ 0.0005,  0.0130, -0.0386,  ...,  0.0400, -0.0048, -0.0083],
#                       [ 0.0049,  0.0313,  0.0132,  ...,  0.0474,  0.1521, -0.0703],
#                       [-0.0491,  0.1571,  0.0497,  ...,  0.0649,  0.0067,  0.1678],
#                       ...,
#                       [-0.0545,  0.0142, -0.0348,  ...,  0.0052, -0.0019, -0.0178],
#                       [ 0.0694,  0.0662, -0.0158,  ...,  0.0011, -0.2074,  0.1599],
#                       [-0.0259, -0.0151, -0.0444,  ...,  0.0315, -0.0126,  0.0163]])),
#              ('model.encoder.layer.2.intermediate.dense.bias',
#               tensor([-0.1503, -0.0069, -0.0048,  ..., -0.0538, -0.0166, -0.2431])),
#              ('model.encoder.layer.2.output.dense.weight',
#               tensor([[-0.0156,  0.0961, -0.0572,  ..., -0.0524, -0.0276, -0.0213],
#                       [ 0.0148,  0.0138,  0.1047,  ...,  0.0387,  0.0358,  0.0264],
#                       [-0.0300, -0.0179, -0.1124,  ..., -0.0290,  0.0574, -0.0351],
#                       ...,
#                       [ 0.0099, -0.0575, -0.0932,  ...,  0.0156, -0.0838,  0.0050],
#                       [ 0.0051,  0.0457, -0.0220,  ...,  0.0050,  0.1424, -0.0133],
#                       [-0.0039, -0.0509,  0.0718,  ..., -0.0027, -0.0650,  0.0220]])),
#              ('model.encoder.layer.2.output.dense.bias',
#               tensor([ 0.0197,  0.0448,  0.0727,  ..., -0.0572, -0.0031,  0.0130])),
#              ('model.encoder.layer.2.LayerNorm.weight',
#               tensor([0.3839, 0.2934, 0.4406,  ..., 0.4303, 0.2801, 0.2842])),
#              ('model.encoder.layer.2.LayerNorm.bias',
#               tensor([ 0.0286, -0.0287,  0.0045,  ..., -0.0879, -0.0161,  0.0269])),
#              ('model.encoder.layer.3.attention.self.query.weight',
#               tensor([[-3.1031e-02, -6.7677e-02,  2.1492e-02,  ...,  1.0042e-01,
#                         9.2291e-02, -4.8545e-02],
#                       [-5.1178e-02, -4.0434e-02,  1.6741e-01,  ...,  3.0570e-02,
#                        -3.8031e-02,  3.6922e-02],
#                       [ 1.9197e-01, -2.7374e-01,  2.3736e-02,  ...,  2.1602e-01,
#                        -9.9894e-02,  3.3423e-03],
#                       ...,
#                       [-5.8708e-02, -1.4101e-04,  4.7613e-02,  ...,  2.6650e-02,
#                         8.1596e-02,  1.1928e-01],
#                       [ 5.0551e-02, -9.9336e-02,  2.1577e-01,  ..., -8.9315e-02,
#                         1.7838e-01, -9.7281e-02],
#                       [-5.6163e-02, -3.2533e-02,  3.0622e-03,  ...,  1.7698e-01,
#                        -8.9364e-02,  4.3972e-02]])),
#              ('model.encoder.layer.3.attention.self.query.bias',
#               tensor([-0.0375, -0.3056, -0.0355,  ...,  0.0372,  0.0011, -0.0179])),
#              ('model.encoder.layer.3.attention.self.key.weight',
#               tensor([[ 0.0966, -0.0118,  0.0328,  ..., -0.0433, -0.0123, -0.0044],
#                       [ 0.1005, -0.1231,  0.0731,  ...,  0.0071, -0.1180,  0.0648],
#                       [-0.0245, -0.0226, -0.1445,  ...,  0.0636, -0.0452,  0.0572],
#                       ...,
#                       [-0.0055, -0.0006, -0.2400,  ..., -0.0996,  0.0904,  0.0689],
#                       [-0.0942, -0.1997,  0.0984,  ..., -0.0393,  0.0577, -0.0784],
#                       [-0.0768,  0.0397, -0.0059,  ..., -0.0622, -0.0704,  0.0736]])),
#              ('model.encoder.layer.3.attention.self.key.bias',
#               tensor([-0.1473, -0.2824,  0.0091,  ..., -0.1230, -0.0486, -0.0694])),
#              ('model.encoder.layer.3.attention.self.value.weight',
#               tensor([[-0.0735, -0.0492,  0.0120,  ..., -0.0460, -0.0178,  0.0335],
#                       [-0.0047, -0.0296,  0.1164,  ...,  0.0008,  0.0630,  0.0604],
#                       [ 0.0147,  0.0268,  0.0566,  ..., -0.0359, -0.0268,  0.0700],
#                       ...,
#                       [-0.0601, -0.0675,  0.0100,  ..., -0.1492,  0.0872,  0.1108],
#                       [-0.0229, -0.0129,  0.0347,  ...,  0.0707, -0.0012, -0.0149],
#                       [ 0.1204, -0.0339,  0.0631,  ..., -0.0585, -0.0215,  0.0500]])),
#              ('model.encoder.layer.3.attention.self.value.bias',
#               tensor([ 0.0033, -0.0105, -0.0009,  ...,  0.0020,  0.0009, -0.0026])),
#              ('model.encoder.layer.3.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.3.attention.output.dense.weight',
#               tensor([[ 0.0344, -0.0513, -0.0491,  ...,  0.0728, -0.1359, -0.0600],
#                       [-0.0500, -0.0996, -0.1069,  ..., -0.1026, -0.2156, -0.1888],
#                       [-0.0118, -0.0783, -0.0520,  ..., -0.1273, -0.0368,  0.0600],
#                       ...,
#                       [ 0.0596, -0.0691, -0.0307,  ..., -0.0126,  0.1313, -0.0482],
#                       [ 0.1600,  0.0275,  0.0449,  ...,  0.0071,  0.1458, -0.0144],
#                       [-0.0639, -0.0747, -0.0996,  ..., -0.0325,  0.0103,  0.1377]])),
#              ('model.encoder.layer.3.attention.output.dense.bias',
#               tensor([ 0.0327,  0.0249,  0.0649,  ..., -0.0670,  0.0159,  0.0265])),
#              ('model.encoder.layer.3.attention.LayerNorm.weight',
#               tensor([0.2432, 0.2287, 0.1884,  ..., 0.2192, 0.2200, 0.1895])),
#              ('model.encoder.layer.3.attention.LayerNorm.bias',
#               tensor([-0.0425,  0.0128, -0.0374,  ...,  0.0158, -0.0086, -0.0213])),
#              ('model.encoder.layer.3.intermediate.dense.weight',
#               tensor([[-0.0232,  0.0171, -0.0034,  ...,  0.0942,  0.0467,  0.0106],
#                       [-0.2530, -0.0014,  0.0166,  ...,  0.1574, -0.0598,  0.1158],
#                       [-0.0205, -0.0174, -0.0460,  ...,  0.0274,  0.0099, -0.0403],
#                       ...,
#                       [-0.0453, -0.0059, -0.0534,  ...,  0.0425, -0.0157, -0.0104],
#                       [-0.0282,  0.0228,  0.0487,  ...,  0.0606,  0.1552, -0.0009],
#                       [ 0.0588, -0.0732, -0.0292,  ..., -0.0369,  0.1195, -0.0589]])),
#              ('model.encoder.layer.3.intermediate.dense.bias',
#               tensor([-0.1612, -0.0182, -0.1569,  ..., -0.1869,  0.0019, -0.0293])),
#              ('model.encoder.layer.3.output.dense.weight',
#               tensor([[-0.0316, -0.0245, -0.0380,  ..., -0.0134,  0.1370, -0.0303],
#                       [ 0.0347, -0.0593,  0.0191,  ...,  0.0289, -0.1667,  0.0539],
#                       [-0.0355, -0.0002,  0.0163,  ...,  0.0123,  0.1423,  0.0757],
#                       ...,
#                       [ 0.0166, -0.0511, -0.0021,  ..., -0.0022,  0.1031,  0.0215],
#                       [-0.0157, -0.1347, -0.0263,  ..., -0.0292, -0.0166,  0.0285],
#                       [-0.0400, -0.0165, -0.0204,  ...,  0.0199, -0.1129,  0.2183]])),
#              ('model.encoder.layer.3.output.dense.bias',
#               tensor([-0.0126,  0.0486,  0.0188,  ..., -0.0080, -0.0177,  0.0007])),
#              ('model.encoder.layer.3.LayerNorm.weight',
#               tensor([0.3832, 0.3176, 0.5067,  ..., 0.4364, 0.3373, 0.3744])),
#              ('model.encoder.layer.3.LayerNorm.bias',
#               tensor([ 0.1067, -0.0579,  0.1059,  ..., -0.1459,  0.0560,  0.0579])),
#              ('model.encoder.layer.4.attention.self.query.weight',
#               tensor([[-6.6196e-02, -1.4649e-01, -1.5757e-01,  ..., -3.9732e-02,
#                         1.4669e-01, -7.4850e-02],
#                       [-2.2521e-02, -6.5022e-02,  2.3930e-02,  ..., -1.6715e-01,
#                         7.1043e-02, -2.6536e-02],
#                       [-9.6444e-02,  4.2111e-02, -1.3581e-01,  ...,  2.2895e-01,
#                         1.4233e-01, -1.1036e-02],
#                       ...,
#                       [-1.6640e-01, -2.3491e-02, -6.1459e-02,  ..., -1.0529e-01,
#                        -6.8825e-02,  7.8812e-03],
#                       [ 8.9498e-02,  9.5617e-02,  3.7616e-03,  ..., -3.9031e-02,
#                        -1.0403e-01,  1.1771e-02],
#                       [ 2.2030e-02, -1.0221e-04, -1.6601e-01,  ...,  4.6233e-02,
#                         8.4872e-02,  8.5626e-02]])),
#              ('model.encoder.layer.4.attention.self.query.bias',
#               tensor([-0.2370,  0.0110, -0.0043,  ...,  0.0047, -0.0053,  0.0233])),
#              ('model.encoder.layer.4.attention.self.key.weight',
#               tensor([[-0.0654,  0.1477, -0.0022,  ...,  0.0176, -0.0908,  0.0818],
#                       [-0.0385,  0.0246, -0.2044,  ..., -0.1237,  0.0359,  0.0987],
#                       [-0.1666,  0.0407, -0.0419,  ..., -0.1349,  0.1769, -0.1743],
#                       ...,
#                       [ 0.0497, -0.0088,  0.1734,  ...,  0.1367, -0.0896,  0.0028],
#                       [-0.1156, -0.0220,  0.0450,  ..., -0.0382,  0.0265,  0.1635],
#                       [ 0.2303, -0.0187, -0.0444,  ..., -0.1225, -0.1627, -0.0388]])),
#              ('model.encoder.layer.4.attention.self.key.bias',
#               tensor([ 0.3557, -0.0185,  0.0012,  ..., -0.1130,  0.0539, -0.0224])),
#              ('model.encoder.layer.4.attention.self.value.weight',
#               tensor([[-0.0713,  0.0282, -0.0146,  ..., -0.1607,  0.2975,  0.1138],
#                       [ 0.0851, -0.1107,  0.0769,  ..., -0.0396, -0.1429,  0.0211],
#                       [-0.0090,  0.0396, -0.1256,  ..., -0.0687,  0.0651, -0.1878],
#                       ...,
#                       [ 0.1082,  0.0164, -0.1231,  ...,  0.1006,  0.0151, -0.1094],
#                       [-0.0609, -0.0117,  0.0273,  ..., -0.0067, -0.1583,  0.0658],
#                       [ 0.0888, -0.1020, -0.1569,  ..., -0.1028, -0.1094,  0.0573]])),
#              ('model.encoder.layer.4.attention.self.value.bias',
#               tensor([ 0.0048,  0.0096,  0.0091,  ...,  0.0051,  0.0093, -0.0047])),
#              ('model.encoder.layer.4.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.4.attention.output.dense.weight',
#               tensor([[-0.0592, -0.0472,  0.0669,  ..., -0.0641, -0.0314, -0.0387],
#                       [ 0.0558,  0.0529,  0.0057,  ..., -0.0689, -0.0699,  0.0309],
#                       [ 0.0091, -0.0817,  0.1057,  ...,  0.0490,  0.0653,  0.0826],
#                       ...,
#                       [ 0.0711,  0.0915,  0.0420,  ..., -0.0890,  0.1733,  0.0849],
#                       [-0.1381,  0.0596,  0.0161,  ..., -0.0005,  0.1360, -0.0155],
#                       [-0.1219, -0.0069,  0.0453,  ...,  0.0786, -0.0746, -0.1355]])),
#              ('model.encoder.layer.4.attention.output.dense.bias',
#               tensor([-0.0181,  0.0413,  0.0193,  ..., -0.0028, -0.0074, -0.0034])),
#              ('model.encoder.layer.4.attention.LayerNorm.weight',
#               tensor([0.2609, 0.2442, 0.2076,  ..., 0.2426, 0.2558, 0.2091])),
#              ('model.encoder.layer.4.attention.LayerNorm.bias',
#               tensor([-0.0166, -0.0065, -0.0350,  ...,  0.0047, -0.0026, -0.0039])),
#              ('model.encoder.layer.4.intermediate.dense.weight',
#               tensor([[-0.1299,  0.0830,  0.1330,  ...,  0.1032, -0.1344, -0.0131],
#                       [ 0.0480,  0.1607, -0.1793,  ..., -0.1340, -0.0780, -0.1013],
#                       [ 0.1324, -0.0036, -0.0483,  ..., -0.1091, -0.1395,  0.0246],
#                       ...,
#                       [ 0.0203, -0.0034, -0.0692,  ..., -0.0548,  0.0372, -0.0577],
#                       [ 0.0837,  0.0274, -0.0299,  ..., -0.0401,  0.0090, -0.1249],
#                       [ 0.0466,  0.0071,  0.0079,  ..., -0.0494, -0.1189,  0.0683]])),
#              ('model.encoder.layer.4.intermediate.dense.bias',
#               tensor([-0.0537, -0.0212, -0.0530,  ..., -0.0363, -0.0996, -0.0489])),
#              ('model.encoder.layer.4.output.dense.weight',
#               tensor([[-0.0850,  0.0040,  0.0624,  ..., -0.1011,  0.0431, -0.0883],
#                       [ 0.0508,  0.2038,  0.1072,  ...,  0.0881, -0.1485,  0.0124],
#                       [ 0.0514, -0.0422, -0.0499,  ...,  0.0269,  0.0581,  0.1143],
#                       ...,
#                       [-0.0422, -0.0448, -0.0177,  ...,  0.0176, -0.0132,  0.0498],
#                       [-0.0242,  0.0064, -0.0465,  ..., -0.0834, -0.0007, -0.1095],
#                       [-0.0159, -0.0229,  0.0967,  ...,  0.0455,  0.0295,  0.1233]])),
#              ('model.encoder.layer.4.output.dense.bias',
#               tensor([-0.0541,  0.0502,  0.0327,  ..., -0.0080, -0.0251, -0.0074])),
#              ('model.encoder.layer.4.LayerNorm.weight',
#               tensor([0.4678, 0.4216, 0.4272,  ..., 0.3996, 0.3742, 0.4577])),
#              ('model.encoder.layer.4.LayerNorm.bias',
#               tensor([ 0.0683, -0.0150, -0.0124,  ..., -0.0145,  0.0151,  0.0258])),
#              ('model.encoder.layer.5.attention.self.query.weight',
#               tensor([[ 0.0455,  0.0555,  0.0712,  ..., -0.1959, -0.0375, -0.1490],
#                       [ 0.1975, -0.0712,  0.0386,  ...,  0.1613, -0.1085,  0.0446],
#                       [ 0.0218,  0.1250, -0.0219,  ..., -0.0797,  0.0503, -0.2129],
#                       ...,
#                       [-0.0484, -0.1376,  0.0248,  ..., -0.0553, -0.0990, -0.0855],
#                       [ 0.0150, -0.0490, -0.1811,  ...,  0.0224, -0.0007,  0.0563],
#                       [-0.0036,  0.0828, -0.0898,  ...,  0.1123,  0.0905, -0.0453]])),
#              ('model.encoder.layer.5.attention.self.query.bias',
#               tensor([ 0.0666,  0.0104,  0.1503,  ..., -0.2053,  0.0442,  0.0092])),
#              ('model.encoder.layer.5.attention.self.key.weight',
#               tensor([[ 0.0606,  0.0772, -0.0746,  ..., -0.1176,  0.1012,  0.0053],
#                       [-0.0037, -0.0719, -0.0641,  ...,  0.0517,  0.1183, -0.0017],
#                       [ 0.0085, -0.0843,  0.0362,  ..., -0.0447, -0.0203, -0.0227],
#                       ...,
#                       [-0.0075,  0.0447,  0.0681,  ...,  0.2097, -0.0989, -0.0415],
#                       [ 0.0618, -0.0430,  0.0639,  ..., -0.0289, -0.0732, -0.1226],
#                       [ 0.1122, -0.0321, -0.1254,  ..., -0.0543,  0.0442,  0.0547]])),
#              ('model.encoder.layer.5.attention.self.key.bias',
#               tensor([ 0.0570,  0.0193,  0.1499,  ...,  0.1409, -0.0185, -0.0633])),
#              ('model.encoder.layer.5.attention.self.value.weight',
#               tensor([[-0.0208, -0.0998,  0.0617,  ...,  0.0194,  0.0211,  0.1439],
#                       [-0.0323,  0.0230,  0.0980,  ...,  0.0787, -0.1657, -0.0492],
#                       [-0.0462,  0.0597, -0.0038,  ..., -0.0242, -0.1241, -0.0296],
#                       ...,
#                       [ 0.0569,  0.0825,  0.0015,  ..., -0.1006,  0.0206, -0.0318],
#                       [-0.0440,  0.1352,  0.0078,  ...,  0.0677,  0.0242, -0.2635],
#                       [ 0.0784, -0.0047, -0.0498,  ...,  0.1350,  0.0964,  0.0451]])),
#              ('model.encoder.layer.5.attention.self.value.bias',
#               tensor([ 0.0074, -0.0009,  0.0087,  ...,  0.0077, -0.0084,  0.0016])),
#              ('model.encoder.layer.5.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.5.attention.output.dense.weight',
#               tensor([[-0.0339, -0.0373, -0.0480,  ..., -0.0885, -0.1754, -0.0185],
#                       [-0.0762, -0.0287, -0.0344,  ..., -0.0955, -0.0845, -0.0787],
#                       [-0.0660, -0.0781,  0.0441,  ...,  0.1119, -0.1814,  0.0516],
#                       ...,
#                       [ 0.0124,  0.0727,  0.0611,  ...,  0.0102, -0.2100, -0.1266],
#                       [ 0.0850,  0.1108, -0.0014,  ..., -0.1195, -0.2461, -0.0894],
#                       [-0.1396, -0.0775,  0.1415,  ...,  0.1297,  0.1086, -0.0280]])),
#              ('model.encoder.layer.5.attention.output.dense.bias',
#               tensor([-0.0305,  0.0192,  0.0194,  ..., -0.0177, -0.0158, -0.0099])),
#              ('model.encoder.layer.5.attention.LayerNorm.weight',
#               tensor([0.2872, 0.2382, 0.2132,  ..., 0.2199, 0.2777, 0.2571])),
#              ('model.encoder.layer.5.attention.LayerNorm.bias',
#               tensor([-0.0409,  0.0127, -0.0197,  ...,  0.0064, -0.0174, -0.0150])),
#              ('model.encoder.layer.5.intermediate.dense.weight',
#               tensor([[ 0.0789,  0.0644,  0.0116,  ..., -0.0999,  0.0276, -0.0275],
#                       [-0.0464, -0.1684,  0.0890,  ..., -0.1897, -0.1165, -0.0389],
#                       [-0.0382, -0.0481,  0.0021,  ...,  0.0425,  0.1884,  0.1145],
#                       ...,
#                       [-0.0373,  0.0017, -0.1130,  ...,  0.0102, -0.1236,  0.0256],
#                       [ 0.1155,  0.0599, -0.0981,  ..., -0.0551,  0.0475,  0.2018],
#                       [-0.2491,  0.0584, -0.0011,  ..., -0.0978, -0.1713, -0.0499]])),
#              ('model.encoder.layer.5.intermediate.dense.bias',
#               tensor([-0.0484, -0.0640, -0.0490,  ..., -0.1133, -0.0666, -0.0096])),
#              ('model.encoder.layer.5.output.dense.weight',
#               tensor([[-0.0537, -0.0063,  0.0074,  ..., -0.0829,  0.0797,  0.0035],
#                       [-0.0877, -0.1556,  0.0573,  ...,  0.0299, -0.0395, -0.1100],
#                       [-0.0333,  0.0414,  0.0958,  ..., -0.0088,  0.0173, -0.0418],
#                       ...,
#                       [-0.0089,  0.0032,  0.1905,  ..., -0.0065,  0.0386, -0.1697],
#                       [ 0.0572, -0.0666,  0.0653,  ...,  0.0723, -0.1240, -0.1401],
#                       [-0.1114,  0.0010,  0.0632,  ..., -0.0480,  0.0587,  0.0104]])),
#              ('model.encoder.layer.5.output.dense.bias',
#               tensor([-0.0166,  0.0032,  0.0376,  ..., -0.0261, -0.0395, -0.0107])),
#              ('model.encoder.layer.5.LayerNorm.weight',
#               tensor([0.4611, 0.4583, 0.4728,  ..., 0.4502, 0.3655, 0.4652])),
#              ('model.encoder.layer.5.LayerNorm.bias',
#               tensor([-0.0133,  0.0081,  0.0084,  ..., -0.0200,  0.0155, -0.0136])),
#              ('model.encoder.layer.6.attention.self.query.weight',
#               tensor([[ 0.0166, -0.0745,  0.0639,  ...,  0.0276, -0.0759, -0.0243],
#                       [ 0.0832,  0.0656, -0.0835,  ...,  0.1388, -0.0088,  0.0221],
#                       [-0.0056, -0.1302,  0.0206,  ..., -0.0237, -0.0314,  0.0277],
#                       ...,
#                       [-0.1727, -0.0336,  0.1190,  ...,  0.0201,  0.1013,  0.2397],
#                       [-0.0508,  0.0394, -0.0786,  ..., -0.0375,  0.0853,  0.0477],
#                       [ 0.0250, -0.0760,  0.0448,  ...,  0.0415,  0.0944, -0.1856]])),
#              ('model.encoder.layer.6.attention.self.query.bias',
#               tensor([ 0.0392,  0.0048, -0.0029,  ...,  0.2003, -0.6322,  0.0518])),
#              ('model.encoder.layer.6.attention.self.key.weight',
#               tensor([[-0.0054, -0.1159, -0.0081,  ..., -0.1346, -0.0315, -0.0089],
#                       [ 0.0360, -0.0715,  0.0568,  ...,  0.1320,  0.0088,  0.0759],
#                       [-0.0503, -0.0664,  0.0295,  ..., -0.0368, -0.0197, -0.0377],
#                       ...,
#                       [-0.2009, -0.1113,  0.0904,  ..., -0.1300, -0.1177,  0.1978],
#                       [ 0.0872, -0.0051,  0.2518,  ...,  0.0688,  0.2350, -0.0088],
#                       [-0.1664, -0.0386, -0.2061,  ...,  0.0653,  0.0264, -0.0034]])),
#              ('model.encoder.layer.6.attention.self.key.bias',
#               tensor([ 0.0241, -0.0124,  0.0237,  ...,  0.1646, -0.0786,  0.0748])),
#              ('model.encoder.layer.6.attention.self.value.weight',
#               tensor([[ 0.1344, -0.0379,  0.0594,  ...,  0.0668, -0.0634,  0.0854],
#                       [-0.0537, -0.1352, -0.0816,  ..., -0.0301,  0.0366,  0.0276],
#                       [ 0.0512,  0.0388, -0.0402,  ..., -0.1150, -0.0004, -0.0632],
#                       ...,
#                       [-0.0085,  0.0227, -0.0293,  ...,  0.0261,  0.0309, -0.0074],
#                       [ 0.0052,  0.0799,  0.1864,  ...,  0.0249,  0.0753,  0.1147],
#                       [-0.0577, -0.0385,  0.0851,  ..., -0.0447, -0.0537,  0.1140]])),
#              ('model.encoder.layer.6.attention.self.value.bias',
#               tensor([-0.0108,  0.0074, -0.0115,  ..., -0.0005, -0.0132,  0.0109])),
#              ('model.encoder.layer.6.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.6.attention.output.dense.weight',
#               tensor([[ 0.0103, -0.0017,  0.0464,  ..., -0.0845, -0.0148,  0.0463],
#                       [-0.0614, -0.0249,  0.0786,  ...,  0.0377, -0.0229,  0.0605],
#                       [-0.0484,  0.1840, -0.0143,  ...,  0.1965,  0.0135, -0.0633],
#                       ...,
#                       [-0.0358,  0.0388, -0.1906,  ..., -0.0797, -0.0022, -0.0225],
#                       [-0.1550,  0.1810,  0.0503,  ...,  0.0006,  0.0136,  0.0226],
#                       [-0.0772,  0.0346, -0.0367,  ...,  0.0205,  0.1455, -0.1615]])),
#              ('model.encoder.layer.6.attention.output.dense.bias',
#               tensor([-0.0357, -0.0005,  0.0357,  ..., -0.0020, -0.0046, -0.0198])),
#              ('model.encoder.layer.6.attention.LayerNorm.weight',
#               tensor([0.2779, 0.2678, 0.2412,  ..., 0.2612, 0.2821, 0.2674])),
#              ('model.encoder.layer.6.attention.LayerNorm.bias',
#               tensor([ 0.0126, -0.0014, -0.0424,  ..., -0.0152, -0.0569,  0.0008])),
#              ('model.encoder.layer.6.intermediate.dense.weight',
#               tensor([[-0.0527, -0.0969, -0.1129,  ..., -0.0935, -0.0956, -0.0887],
#                       [-0.0104,  0.0500,  0.0719,  ...,  0.0343, -0.1014,  0.0678],
#                       [ 0.0795,  0.0843, -0.1291,  ..., -0.0027,  0.0208,  0.0713],
#                       ...,
#                       [ 0.0157,  0.0690, -0.0441,  ...,  0.0148,  0.0558, -0.1076],
#                       [-0.0321,  0.0931, -0.0292,  ..., -0.1453, -0.0454, -0.0377],
#                       [-0.0564,  0.1448,  0.0357,  ..., -0.1409, -0.0919, -0.0230]])),
#              ('model.encoder.layer.6.intermediate.dense.bias',
#               tensor([-0.0938, -0.0876, -0.0701,  ..., -0.0843, -0.0604, -0.0474])),
#              ('model.encoder.layer.6.output.dense.weight',
#               tensor([[-0.0717, -0.0075,  0.0409,  ..., -0.0881,  0.0263,  0.1551],
#                       [ 0.0245,  0.0357, -0.0578,  ...,  0.0107,  0.0630,  0.0566],
#                       [ 0.0597,  0.1302,  0.0416,  ...,  0.0705, -0.1108,  0.0127],
#                       ...,
#                       [ 0.0036,  0.0685, -0.0387,  ...,  0.0074, -0.2184,  0.0140],
#                       [-0.0245, -0.0170, -0.0393,  ...,  0.0302, -0.0119,  0.0452],
#                       [-0.0545,  0.0192,  0.0449,  ...,  0.0187,  0.1096, -0.0256]])),
#              ('model.encoder.layer.6.output.dense.bias',
#               tensor([-0.0109, -0.0267,  0.0374,  ..., -0.0027, -0.0736, -0.0006])),
#              ('model.encoder.layer.6.LayerNorm.weight',
#               tensor([0.4637, 0.4630, 0.4996,  ..., 0.4546, 0.4267, 0.4622])),
#              ('model.encoder.layer.6.LayerNorm.bias',
#               tensor([ 0.0300, -0.0275,  0.0784,  ..., -0.0217,  0.0858, -0.0093])),
#              ('model.encoder.layer.7.attention.self.query.weight',
#               tensor([[-0.0303,  0.0378,  0.0831,  ...,  0.0776, -0.0322, -0.0343],
#                       [-0.0611,  0.1275,  0.0070,  ..., -0.1232,  0.0432,  0.1255],
#                       [ 0.1045, -0.0407, -0.0409,  ..., -0.1120, -0.1226, -0.0593],
#                       ...,
#                       [-0.0827, -0.0546,  0.0564,  ...,  0.0182, -0.1618, -0.0087],
#                       [ 0.0690,  0.1016,  0.0913,  ...,  0.1653, -0.0266,  0.0851],
#                       [-0.0733, -0.0528, -0.0924,  ...,  0.0231,  0.2575,  0.0716]])),
#              ('model.encoder.layer.7.attention.self.query.bias',
#               tensor([ 0.1072, -0.0221, -0.0923,  ..., -0.1034, -0.0307,  0.0494])),
#              ('model.encoder.layer.7.attention.self.key.weight',
#               tensor([[-0.0829, -0.0164,  0.0175,  ...,  0.0364, -0.1260,  0.0099],
#                       [ 0.0072,  0.0216,  0.1653,  ..., -0.0946, -0.0365, -0.0147],
#                       [ 0.1015,  0.0211,  0.1346,  ..., -0.0571,  0.0151,  0.0439],
#                       ...,
#                       [ 0.0091,  0.0078,  0.0274,  ..., -0.0104, -0.1622, -0.0489],
#                       [ 0.1160, -0.0865,  0.0764,  ...,  0.2678, -0.1385,  0.0573],
#                       [ 0.1395,  0.0960,  0.1894,  ...,  0.0288,  0.0012,  0.0668]])),
#              ('model.encoder.layer.7.attention.self.key.bias',
#               tensor([-0.0407,  0.0354,  0.0204,  ..., -0.0649,  0.0901,  0.0745])),
#              ('model.encoder.layer.7.attention.self.value.weight',
#               tensor([[ 0.0800, -0.0242, -0.0416,  ..., -0.1304, -0.0063,  0.0173],
#                       [-0.0762, -0.1028, -0.1066,  ...,  0.1581,  0.0291,  0.0784],
#                       [ 0.0398, -0.0893, -0.0670,  ...,  0.0464,  0.1273,  0.0430],
#                       ...,
#                       [-0.0619,  0.1209,  0.0832,  ...,  0.0450, -0.0222, -0.2200],
#                       [-0.0837, -0.1236, -0.0058,  ...,  0.0200,  0.0282,  0.0403],
#                       [-0.0192,  0.0248, -0.0252,  ..., -0.1222,  0.0710, -0.1108]])),
#              ('model.encoder.layer.7.attention.self.value.bias',
#               tensor([ 0.0101,  0.0004,  0.0020,  ...,  0.0037, -0.0170,  0.0060])),
#              ('model.encoder.layer.7.attention.self.rotary_embeddings.inv_freq',
#               tensor([1.0000e+00, 7.5000e-01, 5.6250e-01, 4.2163e-01, 3.1616e-01, 2.3718e-01,
#                       1.7786e-01, 1.3330e-01, 9.9976e-02, 7.5012e-02, 5.6244e-02, 4.2175e-02,
#                       3.1616e-02, 2.3712e-02, 1.7776e-02, 1.3336e-02, 1.0002e-02, 7.4997e-03,
#                       5.6229e-03, 4.2152e-03, 3.1624e-03, 2.3708e-03, 1.7786e-03, 1.3332e-03,
#                       1.0004e-03, 7.5006e-04, 5.6219e-04, 4.2176e-04, 3.1614e-04, 2.3711e-04,
#                       1.7786e-04, 1.3340e-04])),
#              ('model.encoder.layer.7.attention.output.dense.weight',
#               tensor([[-0.0362, -0.0301,  0.0190,  ..., -0.0504,  0.0886,  0.0546],
#                       [-0.0113, -0.0288,  0.1803,  ..., -0.1407,  0.0486, -0.0037],
#                       [ 0.1165,  0.1628,  0.0357,  ..., -0.2204, -0.0589, -0.0718],
#                       ...,
#                       [ 0.0797, -0.1249, -0.0443,  ..., -0.0043, -0.0430,  0.0318],
#                       [-0.0327,  0.0261, -0.0966,  ..., -0.0412, -0.0540,  0.0203],
#                       [ 0.0651, -0.0642, -0.1570,  ...,  0.1873, -0.0146,  0.2062]])),
#              ('model.encoder.layer.7.attention.output.dense.bias',
#               tensor([-0.0142, -0.0201, -0.0009,  ..., -0.0034, -0.0254, -0.0255])),
#              ('model.encoder.layer.7.attention.LayerNorm.weight',
#               tensor([0.3043, 0.2763, 0.2597,  ..., 0.3063, 0.3059, 0.2805])),
#              ('model.encoder.layer.7.attention.LayerNorm.bias',
#               tensor([-0.0396, -0.0351, -0.0284,  ...,  0.0223, -0.0961,  0.0205])),
#              ('model.encoder.layer.7.intermediate.dense.weight',
#               tensor([[ 0.1594, -0.0514,  0.0073,  ...,  0.1420, -0.1593,  0.0534],
#                       [-0.1078, -0.1054, -0.0859,  ...,  0.0764, -0.0124,  0.1207],
#                       [ 0.0776,  0.0490, -0.1242,  ...,  0.0186,  0.0162, -0.0386],
#                       ...,
#                       [ 0.0187, -0.0599,  0.0059,  ..., -0.0299,  0.0818, -0.0233],
#                       [-0.0898, -0.0879, -0.1600,  ..., -0.0811, -0.0227, -0.0677],
#                       [-0.0189,  0.0419, -0.0165,  ...,  0.1051, -0.1314,  0.1589]])),
#              ('model.encoder.layer.7.intermediate.dense.bias',
#               tensor([-0.0432, -0.0296, -0.0645,  ..., -0.0717, -0.0852, -0.0497])),
#              ('model.encoder.layer.7.output.dense.weight',
#               tensor([[ 0.0089,  0.0253,  0.0889,  ...,  0.1006, -0.0067,  0.0567],
#                       [-0.0438,  0.1110, -0.0298,  ..., -0.1902, -0.1567, -0.0087],
#                       [-0.1014,  0.0276,  0.0026,  ...,  0.0934, -0.0713, -0.0394],
#                       ...,
#                       [ 0.0128, -0.0853,  0.0124,  ...,  0.0037, -0.1031, -0.0568],
#                       [-0.0525, -0.0426, -0.0546,  ...,  0.0473,  0.0138,  0.0558],
#                       [ 0.0709, -0.1689, -0.0085,  ..., -0.0399, -0.1608,  0.0984]])),
#              ('model.encoder.layer.7.output.dense.bias',
#               tensor([ 0.0150, -0.0489, -0.0044,  ..., -0.0287, -0.0408, -0.0236])),
#              ('model.encoder.layer.7.LayerNorm.weight',
#               tensor([0.4391, 0.4534, 0.4459,  ..., 0.4552, 0.4108, 0.4541])),
#              ('model.encoder.layer.7.LayerNorm.bias',
#               tensor([-0.0094, -0.0155,  0.0671,  ...,  0.0037, -0.0005,  0.0141])),
#              ('model.encoder.layer.8.attention.self.query.weight',
#               tensor([[-0.0550, -0.0654,  0.0052,  ..., -0.0748, -0.0288,  0.1110],
#                       [ 0.0096,  0.0098,  0.0137,  ..., -0.1044, -0.0668, -0.1095],
#                       [-0.0250, -0.0157,  0.0418,  ..., -0.0827,  0.0650, -0.0030],
#                       ...,
# ...
#              ('model.encoder.layer.32.attention.output.dense.weight',
#               tensor([[-0.0614, -0.1771,  0.0279,  ..., -0.0396, -0.0322,  0.1966],
#                       [ 0.2179,  0.1164, -0.1050,  ...,  0.2445, -0.2348, -0.0708],
#                       [ 0.0559,  0.0394, -0.0432,  ...,  0.1234,  0.0110, -0.1421],
#                       ...,
#                       [-0.0740, -0.0175, -0.0417,  ..., -0.0130, -0.2168,  0.0207],
#                       [-0.0224, -0.0793,  0.0599,  ...,  0.0274,  0.1019, -0.0053],
#                       [-0.2617,  0.0817, -0.0151,  ..., -0.0537, -0.0210,  0.3694]])),
#              ('model.encoder.layer.32.attention.output.dense.bias',
#               tensor([ 0.0904, -0.0586, -0.0612,  ..., -0.1166, -0.0725, -0.0572])),
#              ('model.encoder.layer.32.attention.LayerNorm.weight',
#               tensor([0.4143, 0.3937, 0.3954,  ..., 0.3517, 0.3678, 0.4025])),
#              ('model.encoder.layer.32.attention.LayerNorm.bias',
#               tensor([-0.0359,  0.0498,  0.0188,  ...,  0.0074,  0.0125,  0.0124])),
#              ('model.encoder.layer.32.intermediate.dense.weight',
#               tensor([[-0.0176, -0.0484, -0.0921,  ..., -0.1180,  0.0788, -0.0024],
#                       [-0.0418,  0.0200,  0.1550,  ..., -0.1677,  0.0256, -0.0682],
#                       [-0.0057, -0.0935,  0.0007,  ..., -0.1467,  0.0847, -0.0794],
#                       ...,
#                       [-0.0352, -0.0485, -0.0103,  ...,  0.0478, -0.0007,  0.0059],
#                       [-0.0813, -0.0617,  0.1352,  ...,  0.2700, -0.0622,  0.0304],
#                       [-0.0969,  0.1109, -0.0504,  ...,  0.0110,  0.0433, -0.0930]])),
#              ('model.encoder.layer.32.intermediate.dense.bias',
#               tensor([-0.0063, -0.0173, -0.0491,  ..., -0.0267, -0.0112, -0.0281])),
#              ('model.encoder.layer.32.output.dense.weight',
#               tensor([[ 2.6094e-02, -1.7358e-01,  6.3305e-02,  ...,  2.7059e-01,
#                        -3.7522e-01, -1.9531e-02],
#                       [-9.4935e-02, -1.6791e-01,  3.8845e-02,  ...,  1.7679e-01,
#                        -1.0533e-01,  8.9886e-03],
#                       [ 1.1556e-01, -1.1059e-02,  5.5905e-02,  ...,  2.1250e-01,
#                         3.1155e-01,  3.7527e-01],
#                       ...,
#                       [ 1.0349e-01,  7.6079e-02,  6.6433e-02,  ...,  2.6062e-01,
#                         4.9161e-02,  5.4206e-02],
#                       [-1.4037e-01, -7.6610e-02, -5.7396e-03,  ..., -1.5949e-01,
#                        -7.1658e-02,  1.3921e-01],
#                       [-2.4807e-02,  1.0781e-04, -1.1837e-01,  ..., -1.0654e-01,
#                        -2.1641e-02, -1.0887e-01]])),
#              ('model.encoder.layer.32.output.dense.bias',
#               tensor([ 0.0156, -0.0045, -0.0523,  ..., -0.0713, -0.0617,  0.0440])),
#              ('model.encoder.layer.32.LayerNorm.weight',
#               tensor([0.4608, 0.5144, 0.4786,  ..., 0.4624, 0.4464, 0.4801])),
#              ('model.encoder.layer.32.LayerNorm.bias',
#               tensor([ 0.0034, -0.0434, -0.0029,  ..., -0.0273,  0.0035, -0.0713])),
#              ('model.encoder.emb_layer_norm_after.weight',
#               tensor([0.2352, 0.2603, 0.2513,  ..., 0.2622, 0.2562, 0.2590])),
#              ('model.encoder.emb_layer_norm_after.bias',
#               tensor([-0.0155,  0.0092,  0.0213,  ..., -0.0537,  0.0132,  0.0790])),
#              ('model.pooler.dense.weight',
#               tensor([[ 0.0385,  0.0297,  0.0180,  ..., -0.0023, -0.0126, -0.0253],
#                       [-0.0059, -0.0056,  0.0217,  ..., -0.0335, -0.0389,  0.0020],
#                       [-0.0135, -0.0378, -0.0368,  ..., -0.0310, -0.0286,  0.0041],
#                       ...,
#                       [-0.0016,  0.0117, -0.0140,  ..., -0.0081, -0.0281,  0.0021],
#                       [-0.0125, -0.0080, -0.0207,  ..., -0.0027, -0.0050, -0.0137],
#                       [-0.0449, -0.0260, -0.0030,  ..., -0.0031,  0.0018,  0.0077]])),
#              ('model.pooler.dense.bias',
#               tensor([0., 0., 0.,  ..., 0., 0., 0.])),
#              ('model.contact_head.regression.weight',
#               tensor([[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  8.6607e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.9052e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  8.7018e-02,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.4382e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.1634e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.6754e-01,  0.0000e+00,
#                         0.0000e+00,  4.7571e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  1.8241e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  6.3387e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.1099e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  3.4932e-01, -2.0187e-02,
#                         1.0717e-01,  0.0000e+00,  1.2029e+00,  0.0000e+00,  0.0000e+00,
#                         1.4237e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  7.7550e-01,
#                         2.2187e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  5.7300e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         6.0197e+00,  0.0000e+00,  1.4587e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -1.6267e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.7784e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -3.6329e-02,  2.2149e-01,  0.0000e+00, -1.3990e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -8.3230e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -4.3948e+00,  0.0000e+00, -7.4849e-02, -6.5220e-01,  0.0000e+00,
#                        -2.4335e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1386e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -1.1154e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.7978e-01,  0.0000e+00,  0.0000e+00,
#                        -6.7810e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -2.7959e-01,  0.0000e+00,  1.3830e+00,
#                         0.0000e+00,  7.7892e-01,  0.0000e+00,  0.0000e+00, -9.2584e-01,
#                         5.4742e-03,  0.0000e+00, -8.9198e-02,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -3.0531e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  7.6630e-01,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  5.1623e-01,  2.0175e+00,
#                         8.5277e-02,  0.0000e+00,  0.0000e+00, -3.6948e-01,  0.0000e+00,
#                         0.0000e+00,  6.8948e-02,  0.0000e+00,  0.0000e+00, -7.2590e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  2.9609e-01,  0.0000e+00,
#                        -1.5232e+00,  0.0000e+00,  0.0000e+00,  4.2038e-01,  0.0000e+00,
#                         1.2211e+00,  0.0000e+00,  0.0000e+00,  2.9299e+00, -2.1506e+00,
#                         0.0000e+00,  9.2984e-01,  7.6042e-01, -3.5253e-01,  0.0000e+00,
#                        -1.2273e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00, -8.9307e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  1.0350e-01,  1.7648e-01, -4.1064e-01,  0.0000e+00,
#                        -3.7447e-01,  0.0000e+00,  1.5040e-01,  0.0000e+00,  9.9286e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  7.7144e-02,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         4.4486e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.7663e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.5656e-02,  3.7187e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -6.7643e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -2.8274e-01,
#                         0.0000e+00,  0.0000e+00, -2.2929e-01,  0.0000e+00,  0.0000e+00,
#                         9.4702e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -2.2373e-01,
#                         1.6001e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         1.5397e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  4.1931e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.3743e+00, -6.7316e-03,  0.0000e+00,  9.6804e-01,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -8.7255e-02,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00, -3.4948e-01,  0.0000e+00, -1.4712e-02,
#                         4.6000e-01,  0.0000e+00,  0.0000e+00, -1.2773e-01,  5.4927e-01,
#                         0.0000e+00,  1.1131e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         8.0312e-01,  0.0000e+00,  0.0000e+00,  3.2332e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  8.0039e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00, -1.5197e+00,  0.0000e+00,
#                         0.0000e+00, -1.2544e-01,  0.0000e+00,  0.0000e+00,  9.4995e-01,
#                         4.1188e-01,  0.0000e+00,  0.0000e+00, -1.4186e+00,  0.0000e+00,
#                         0.0000e+00,  2.2519e-01, -1.3035e+00, -3.3026e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         2.9643e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  3.2301e+00,  5.8397e-01,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.8739e-01,  0.0000e+00,
#                         0.0000e+00,  1.0099e+00,  0.0000e+00, -1.1772e+00,  0.0000e+00,
#                         0.0000e+00, -1.1987e-01,  1.9504e+00,  0.0000e+00,  0.0000e+00,
#                         4.8955e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.4301e+00,
#                         1.1284e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                        -1.4012e+00,  0.0000e+00,  3.8097e-01,  1.5137e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.5034e+00,  4.3518e-02,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         3.7862e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  6.7905e-01,  0.0000e+00, -3.4386e+00,
#                         0.0000e+00, -1.4802e-01, -3.9989e-01,  1.4289e-02,  0.0000e+00,
#                         2.6872e+00,  1.6644e+00,  0.0000e+00,  1.7983e+00,  0.0000e+00,
#                         1.5690e+00,  4.3481e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  2.6579e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  2.0364e+00,  0.0000e+00,  0.0000e+00,  1.0977e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.4038e+00,  0.0000e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#                         1.2369e+00,  0.0000e+00,  2.5634e+00,  0.0000e+00,  0.0000e+00,
#                         4.7633e+00,  0.0000e+00,  0.0000e+00,  3.5985e+00,  2.0484e-01,
#                         0.0000e+00,  0.0000e+00,  1.1325e+00,  0.0000e+00,  0.0000e+00,
#                         0.0000e+00,  4.4427e+00,  1.9547e+00,  6.3678e+00,  3.4624e+00,
#                         0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0421e+01,  0.0000e+00]])),
#              ('model.contact_head.regression.bias', tensor([-4.9368])),
#              ('fc.weight',
#               tensor([[-0.0116,  0.0178,  0.0156,  ...,  0.0320,  0.0127, -0.0135]])),
#              ('fc.bias', tensor([-0.0002]))])

# %%
model.fc_dropout2
# Out:
# Dropout(p=0.8, inplace=False)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("/home2/sagawa/PLTNUM/classification_automodel")

# %% [markdown]
# token_embeddingをresizeしてweightを保存

# %%
tokenizer.add_special_tokens({"additional_special_tokens": ["@@@@@@", "ooo"]})
tokenizer
# Out:
# EsmTokenizer(name_or_path='/home2/sagawa/PLTNUM/classification_automodel', vocab_size=33, model_max_length=1000000000000000019884624838656, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<eos>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'cls_token': '<cls>', 'mask_token': '<mask>', 'additional_special_tokens': ['@@@@@@', 'ooo']}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<cls>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("<eos>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32: AddedToken("<mask>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	33: AddedToken("@@@@@@", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	34: AddedToken("ooo", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
model.model.resize_token_embeddings(len(tokenizer))
model.config
# Out:
# EsmConfig {
#   "_name_or_path": "/home2/sagawa/PLTNUM/classification_automodel",
#   "architectures": [
#     "EsmForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "classifier_dropout": null,
#   "emb_layer_norm_before": false,
#   "esmfold_config": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1280,
#   "initializer_range": 0.02,
#   "intermediate_size": 5120,
#   "is_folding_model": false,
#   "layer_norm_eps": 1e-05,
#   "mask_token_id": 32,
#   "max_position_embeddings": 1026,
#   "model_type": "esm",
#   "num_attention_heads": 20,
#   "num_hidden_layers": 33,
#   "pad_token_id": 1,
#   "position_embedding_type": "rotary",
#   "token_dropout": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.38.1",
#   "use_cache": true,
#   "vocab_list": null,
#   "vocab_size": 33
# }

# %%
torch.save(model.state_dict(), "/home2/sagawa/PLTNUM/classification_automodel/pytorch_model.bin")

# %%
model = PLTNUM.from_pretrained("/home2/sagawa/PLTNUM/classification_automodel", cfg)
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at /home2/sagawa/PLTNUM/classification_automodel and are newly initialized: ['contact_head.regression.bias', 'contact_head.regression.weight', 'embeddings.position_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.emb_layer_norm_after.bias', 'encoder.emb_layer_norm_after.weight', 'encoder.layer.0.LayerNorm.bias', 'encoder.layer.0.LayerNorm.weight', 'encoder.layer.0.attention.LayerNorm.bias', 'encoder.layer.0.attention.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.LayerNorm.bias', 'encoder.layer.1.LayerNorm.weight', 'encoder.layer.1.attention.LayerNorm.bias', 'encoder.layer.1.attention.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.LayerNorm.bias', 'encoder.layer.10.LayerNorm.weight', 'encoder.layer.10.attention.LayerNorm.bias', 'encoder.layer.10.attention.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.LayerNorm.bias', 'encoder.layer.11.LayerNorm.weight', 'encoder.layer.11.attention.LayerNorm.bias', 'encoder.layer.11.attention.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.12.LayerNorm.bias', 'encoder.layer.12.LayerNorm.weight', 'encoder.layer.12.attention.LayerNorm.bias', 'encoder.layer.12.attention.LayerNorm.weight', 'encoder.layer.12.attention.output.dense.bias', 'encoder.layer.12.attention.output.dense.weight', 'encoder.layer.12.attention.self.key.bias', 'encoder.layer.12.attention.self.key.weight', 'encoder.layer.12.attention.self.query.bias', 'encoder.layer.12.attention.self.query.weight', 'encoder.layer.12.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.12.attention.self.value.bias', 'encoder.layer.12.attention.sel ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 model = PLTNUM.from_pretrained("/home2/sagawa/PLTNUM/classification_automodel", cfg)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:3502, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3493     if dtype_orig is not None:
#    3494         torch.set_default_dtype(dtype_orig)
#    3495     (
#    3496         model,
#    3497         missing_keys,
#    3498         unexpected_keys,
#    3499         mismatched_keys,
#    3500         offload_index,
#    3501         error_msgs,
# -> 3502     ) = cls._load_pretrained_model(
#    3503         model,
#    3504         state_dict,
#    3505         loaded_state_dict_keys,  # XXX: rename?
#    3506         resolved_archive_file,
#    3507         pretrained_model_name_or_path,
#    3508         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3509         sharded_metadata=sharded_metadata,
#    3510         _fast_init=_fast_init,
#    3511         low_cpu_mem_usage=low_cpu_mem_usage,
#    3512         device_map=device_map,
#    3513         offload_folder=offload_folder,
#    3514         offload_state_dict=offload_state_dict,
#    3515         dtype=torch_dtype,
#    3516         hf_quantizer=hf_quantizer,
#    3517         keep_in_fp32_modules=keep_in_fp32_modules,
#    3518     )
#    3520 # make sure token embedding weights are still tied if needed
#    3521 model.tie_weights()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/modeling_utils.py:3977, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules)
#    3973     if "size mismatch" in error_msg:
#    3974         error_msg += (
#    3975             "\n\tYou may consider adding `ignore_mismatched_sizes=True` in the model `from_pretrained` method."
#    3976         )
# -> 3977     raise RuntimeError(f"Error(s) in loading state_dict for {model.__class__.__name__}:\n\t{error_msg}")
#    3979 if len(unexpected_keys) > 0:
#    3980     archs = [] if model.config.architectures is None else model.config.architectures
#
# RuntimeError: Error(s) in loading state_dict for PLTNUM:
# 	size mismatch for model.embeddings.word_embeddings.weight: copying a param with shape torch.Size([35, 1280]) from checkpoint, the shape in current model is torch.Size([33, 1280]).
# 	You may consider adding `ignore_mismatched_sizes=True` in the model `from_pretrained` method.

# %%
model.config.vocab_size = len(tokenizer)
model.config.save_pretrained("/home2/sagawa/PLTNUM/classification_automodel")

# %%
model = PLTNUM.from_pretrained("/home2/sagawa/PLTNUM/classification_automodel", cfg)
# Out:
# Some weights of EsmModel were not initialized from the model checkpoint at /home2/sagawa/PLTNUM/classification_automodel and are newly initialized: ['contact_head.regression.bias', 'contact_head.regression.weight', 'embeddings.position_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.emb_layer_norm_after.bias', 'encoder.emb_layer_norm_after.weight', 'encoder.layer.0.LayerNorm.bias', 'encoder.layer.0.LayerNorm.weight', 'encoder.layer.0.attention.LayerNorm.bias', 'encoder.layer.0.attention.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.LayerNorm.bias', 'encoder.layer.1.LayerNorm.weight', 'encoder.layer.1.attention.LayerNorm.bias', 'encoder.layer.1.attention.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.LayerNorm.bias', 'encoder.layer.10.LayerNorm.weight', 'encoder.layer.10.attention.LayerNorm.bias', 'encoder.layer.10.attention.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.LayerNorm.bias', 'encoder.layer.11.LayerNorm.weight', 'encoder.layer.11.attention.LayerNorm.bias', 'encoder.layer.11.attention.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.12.LayerNorm.bias', 'encoder.layer.12.LayerNorm.weight', 'encoder.layer.12.attention.LayerNorm.bias', 'encoder.layer.12.attention.LayerNorm.weight', 'encoder.layer.12.attention.output.dense.bias', 'encoder.layer.12.attention.output.dense.weight', 'encoder.layer.12.attention.self.key.bias', 'encoder.layer.12.attention.self.key.weight', 'encoder.layer.12.attention.self.query.bias', 'encoder.layer.12.attention.self.query.weight', 'encoder.layer.12.attention.self.rotary_embeddings.inv_freq', 'encoder.layer.12.attention.self.value.bias', 'encoder.layer.12.attention.sel ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
tokenizer.save_pretrained
